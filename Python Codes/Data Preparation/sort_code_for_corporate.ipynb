# %%
import pandas as pd
import numpy as np

# %%
country = 'Germany'

# %%
df1= pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Dirty_Prices/{country}_cor_dirtyprice.xlsx")
df2= pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_DTM/{country}_cor_dtm.xlsx")
df3= pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Coupon/{country}_cor_coupon.xlsx")
df4 = pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Coupon_Dates/{country}.xlsx")
df5 = pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Macro/Germany_Macro.xlsm", sheet_name = 'TS Sneha')

# %%
df5
# Out:
#                      Name                                       #ERROR  \
# 0                    Code                                          NaN
# 1     2010-01-01 00:00:00  $$ER: 0629,210Y0D         NO DATA AVAILABLE
# 2     2010-01-04 00:00:00                                          NaN
# 3     2010-01-05 00:00:00                                          NaN
# 4     2010-01-06 00:00:00                                          NaN
# ...                   ...                                          ...
# 3540  2023-07-27 00:00:00                                          NaN
# 3541  2023-07-28 00:00:00                                          NaN
# 3542  2023-07-31 00:00:00                                          NaN
# 3543  2023-08-01 00:00:00                                          NaN
# 3544  2023-08-02 00:00:00                                          NaN
#
#                                          #ERROR.1  \
# 0                                             NaN
# 1     $$ER: 0629,207PGG         NO DATA AVAILABLE
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3540                                          NaN
# 3541                                          NaN
# 3542                                          NaN
# 3543                                          NaN
# 3544                                          NaN
#
#                                          #ERROR.2  \
# 0                                             NaN
# 1     $$ER: 0629,605UG4         NO DATA AVAILABLE
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3540                                          NaN
# 3541                                          NaN
# 3542                                          NaN
# 3543                                          NaN
# 3544                                          NaN
#
#                                          #ERROR.3  \
# 0                                             NaN
# 1     $$ER: 0629,5990VT         NO DATA AVAILABLE
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3540                                          NaN
# 3541                                          NaN
# 3542                                          NaN
# 3543                                          NaN
# 3544                                          NaN
#
#                                          #ERROR.4  \
# 0                                             NaN
# 1     $$ER: 0629,796MFU         NO DATA AVAILABLE
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3540                                          NaN
# 3541                                          NaN
# 3542                                          NaN
# 3543                                          NaN
# 3544                                          NaN
#
#                                          #ERROR.5  \
# 0                                             NaN
# 1     $$ER: 0629,949WMQ         NO DATA AVAILABLE
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3540                                          NaN
# 3541                                          NaN
# 3542                                          NaN
# 3543                                          NaN
# 3544                                          NaN
#
#                                          #ERROR.6  \
# 0                                             NaN
# 1     $$ER: 0629,950P0Y         NO DATA AVAILABLE
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3540                                          NaN
# 3541                                          NaN
# 3542                                          NaN
# 3543                                          NaN
# 3544                                          NaN
#
#                                          #ERROR.7  \
# 0                                             NaN
# 1     $$ER: 0629,651KHE         NO DATA AVAILABLE
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 3540                                          NaN
# 3541                                          NaN
# 3542                                          NaN
# 3543                                          NaN
# 3544                                          NaN
#
#                                          #ERROR.8  ...  \
# 0                                             NaN  ...
# 1     $$ER: 0629,9853UZ         NO DATA AVAILABLE  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# ...                                           ...  ...
# 3540                                          NaN  ...
# 3541                                          NaN  ...
# 3542                                          NaN  ...
# 3543                                          NaN  ...
# 3544                                          NaN  ...
#
#      VW INTL FIN NV 2022 3 3/4% 28/09/27 REG.S - GROSS PRICE  \
# 0                                            930JDW(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                           101.4158
# 3541                                           101.7751
# 3542                                           101.6114
# 3543                                           101.5896
# 3544                                           101.7639
#
#      VW INTL FIN NV 2022 3.748%(F/R)PERP. REG.S - GROSS PRICE  \
# 0                                            9097VQ(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                            89.9577
# 3541                                             89.968
# 3542                                            90.1032
# 3543                                            90.2385
# 3544                                            90.1238
#
#      VW INTL FIN NV 2022 4 1/4% 15/02/28 REG.S - GROSS PRICE  \
# 0                                            958FP9(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                           101.4549
# 3541                                           101.8185
# 3542                                           101.8061
# 3543                                           101.7638
# 3544                                           101.9404
#
#      VW INTL FIN NV 2022 4 1/8% 15/11/25 REG.S - GROSS PRICE  \
# 0                                            958FQD(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                           102.5117
# 3541                                            102.567
# 3542                                           102.6063
# 3543                                           102.5656
# 3544                                           102.6809
#
#      VW INTL FIN NV 2022 4 3/8% 15/05/30 REG.S - GROSS PRICE  \
# 0                                            958FP7(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                           100.2554
# 3541                                           100.4613
# 3542                                           100.5873
# 3543                                           100.5173
# 3544                                           100.7162
#
#      VW INTL FIN NV 2022 4.375%(F/R)PERP. REG.S - GROSS PRICE  \
# 0                                            9097VR(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                            85.6192
# 3541                                            85.6311
# 3542                                            85.6431
# 3543                                              85.78
# 3544                                             85.667
#
#      VW INTL FIN NV 2023 3 7/8% 29/03/26 REG.S - GROSS PRICE  \
# 0                                            973URD(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                           100.2258
# 3541                                           100.3254
# 3542                                             100.34
# 3543                                           100.3336
# 3544                                           100.4862
#
#      VW INTL FIN NV 2023 4 1/4% 29/03/29 REG.S - GROSS PRICE  \
# 0                                            973UU7(GP)
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3540                                           100.8328
# 3541                                           100.9175
# 3542                                           101.0751
# 3543                                           101.0007
# 3544                                           101.1613
#
#      VW INTL FIN NV 2023 4.58% 30/05/26 - GROSS PRICE  \
# 0                                          979MZH(GP)
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 3540                                          98.8405
# 3541                                           98.616
# 3542                                          98.5746
# 3543                                          98.5611
# 3544                                          98.5767
#
#      VW INTL FIN NV 2023 4.86% 02/06/25 - GROSS PRICE
# 0                                          9790M1(GP)
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 3540                                          99.5369
# 3541                                          99.4512
# 3542                                          99.4135
# 3543                                          99.4048
# 3544                                          99.4321
#
# [3545 rows x 427 columns]

# %%
df3_code = df3["Code"]

# %%
df3 = df3.drop(columns=['Code'])

# %%
df5.loc[0] = [str(value).split('(')[0].strip() for value in df5.loc[0]]

# %%
dictionary = df5.iloc[0].to_dict()

dictionary2 =  {value: key for key, value in dictionary.items()}

new_key = 'Code'
new_value = 'AAAAAAAAAAAA'

# Append the new key-value pair to the dictionary
dictionary2[new_key] = new_value

# %%
dictionary
# Out:
# {'Name': 'Code',
#  '#ERROR': 'nan',
#  '#ERROR.1': 'nan',
#  '#ERROR.2': 'nan',
#  '#ERROR.3': 'nan',
#  '#ERROR.4': 'nan',
#  '#ERROR.5': 'nan',
#  '#ERROR.6': 'nan',
#  '#ERROR.7': 'nan',
#  '#ERROR.8': 'nan',
#  '#ERROR.9': 'nan',
#  '#ERROR.10': 'nan',
#  '#ERROR.11': 'nan',
#  '#ERROR.12': 'nan',
#  '#ERROR.13': 'nan',
#  '#ERROR.14': 'nan',
#  'BASF SE 2012 2% 05/12/22 12 - GROSS PRICE': '81542Z',
#  'BASF SE 2013 1 7/8% 04/02/21 13 - GROSS PRICE': '83426Y',
#  'BASF SE 2013 2 7/8% 16/05/33 REG.S - GROSS PRICE': '781GAF',
#  'BASF SE 2013 3 1/4% 12/02/43 REG.S - GROSS PRICE': '7902VA',
#  'BASF SE 2013 3% 07/02/33 REG.S - GROSS PRICE': '8511ZH',
#  'BASF SE 2013 3.675% 28/05/25 REG.S - GROSS PRICE': '781H04',
#  'BASF SE 2013 F/R 05/20 Q - GROSS PRICE': '781F1M',
#  'BASF SE 2014 2 1/2% 22/01/24 REG.S - GROSS PRICE': '789DV8',
#  'BASF SE 2016 1 1/2% 04/03/31 REG.S - GROSS PRICE': '826XN1',
#  'BASF SE 2016 2.37% 17/10/31 REG.S - GROSS PRICE': '837PYW',
#  'BASF SE 2016 7/8% 06/10/23 REG.S - GROSS PRICE': '836RJM',
#  'BASF SE 2016 7/8% 06/10/31 REG.S - GROSS PRICE': '836F89',
#  'BASF SE 2017 1 3/4% 11/03/25 REG.S - GROSS PRICE': '841NGU',
#  'BASF SE 2017 1 5/8% 15/11/37 REG.S - GROSS PRICE': '858RDK',
#  'BASF SE 2017 1.45% 13/12/32 REG.S - GROSS PRICE': '841NGK',
#  'BASF SE 2017 2 1/2% 18/01/22 REG.S - GROSS PRICE': '841VV1',
#  'BASF SE 2017 2.67% 03/01/29 REG.S - GROSS PRICE': '841HM1',
#  'BASF SE 2017 7/8% 15/11/27 REG.S - GROSS PRICE': '858RDJ',
#  'BASF SE 2017 F/R 11/19 REG.S - GROSS PRICE': '858RA7',
#  'BASF SE 2018 1 1/2% 22/05/30 REG.S - GROSS PRICE': '206G5U',
#  'BASF SE 2018 1 3/8% 21/06/22 REG.S - GROSS PRICE': '208D0J',
#  'BASF SE 2018 4% 10/08/33 REG.S - GROSS PRICE': '210Z9J',
#  'BASF SE 2018 7/8% 22/05/25 REG.S - GROSS PRICE': '206H4Y',
#  'BASF SE 2019 7/8% 07/03/29 REG.S - GROSS PRICE': '222UMF',
#  'BASF SE 2020 0.101% 05/06/23 REG.S - GROSS PRICE': '608KTX',
#  'BASF SE 2020 1/4% 05/06/27 REG.S - GROSS PRICE': '608KTY',
#  'BASF SE 2022 1 1/2% 17/03/31 REG.S - GROSS PRICE': '908XHH',
#  'BASF SE 2022 3 1/8% 29/06/28 REG.S - GROSS PRICE': '930KXX',
#  'BASF SE 2022 3 3/4% 29/06/32 REG.S - GROSS PRICE': '930KX2',
#  'BASF SE 2022 3/4% 17/03/26 REG.S - GROSS PRICE': '908XFT',
#  'BASF SE 2023 4 1/2% 08/03/35 REG.S - GROSS PRICE': '971AXQ',
#  'BASF SE 2023 4 1/4% 08/03/32 REG.S - GROSS PRICE': '971AX0',
#  'BASF SE 2023 4% 08/03/29 REG.S - GROSS PRICE': '971AXL',
#  'BMW FINANCE NV 2013 2 3/8% 24/01/23 REG.S - GROSS PRICE': '8300MY',
#  'BMW FINANCE NV 2013 2% 04/09/20 REG.S - GROSS PRICE': '784QE7',
#  'BMW FINANCE NV 2014 1 1/4% 05/09/22 REG.S - GROSS PRICE': '797P2M',
#  'BMW FINANCE NV 2014 2 5/8% 17/01/24 REG.S - GROSS PRICE': '78810Z',
#  'BMW FINANCE NV 2015 1 3/4% 06/10/20 - GROSS PRICE': '818PPQ',
#  'BMW FINANCE NV 2015 1 7/8% 29/06/20 REG.S - GROSS PRICE': '811TY6',
#  'BMW FINANCE NV 2015 1% 21/01/25 REG.S - GROSS PRICE': '803R30',
#  'BMW FINANCE NV 2015 1/2% 21/01/20 REG.S - GROSS PRICE': '803R3Z',
#  'BMW FINANCE NV 2015 2 3/8% 01/12/21 REG.S - GROSS PRICE': '821W6E',
#  'BMW FINANCE NV 2015 7/8% 17/11/20 REG.S - GROSS PRICE': '820KGW',
#  'BMW FINANCE NV 2016 0.239% 22/02/23 REG.S - GROSS PRICE': '826FT8',
#  'BMW FINANCE NV 2016 0.454% 29/01/21 REG.S - GROSS PRICE': '824P99',
#  'BMW FINANCE NV 2016 1 3/8% 25/10/19 REG.S - GROSS PRICE': '837PY1',
#  'BMW FINANCE NV 2016 1% 15/02/22 REG.S - GROSS PRICE': '825DT0',
#  'BMW FINANCE NV 2016 1% 18/08/31 REG.S - GROSS PRICE': '834G1A',
#  'BMW FINANCE NV 2016 1/8% 15/04/20 REG.S - GROSS PRICE': '828RH9',
#  'BMW FINANCE NV 2016 2 1/2% 24/08/20 REG.S - GROSS PRICE': '834RN5',
#  'BMW FINANCE NV 2016 2.18% 19/04/21 REG.S - GROSS PRICE': '828T8G',
#  'BMW FINANCE NV 2016 3/4% 15/04/24 REG.S - GROSS PRICE': '828RJH',
#  'BMW FINANCE NV 2016 4 1/4% 04/02/26 REG.S - GROSS PRICE': '824WYM',
#  'BMW FINANCE NV 2016 4 1/4% 23/12/19 REG.S - GROSS PRICE': '840JAH',
#  'BMW FINANCE NV 2016 7/8% 16/08/22 REG.S - GROSS PRICE': '834GJM',
#  'BMW FINANCE NV 2017 1 1/2% 18/01/21 REG.S - GROSS PRICE': '852C35',
#  'BMW FINANCE NV 2017 1.73% 30/06/20 REG.S - GROSS PRICE': '851HVM',
#  'BMW FINANCE NV 2017 1/8% 03/07/20 REG.S - GROSS PRICE': '846JX3',
#  'BMW FINANCE NV 2017 1/8% 12/01/21 REG.S - GROSS PRICE': '841NZW',
#  'BMW FINANCE NV 2017 2 1/2% 06/12/21 REG.S - GROSS PRICE': '859R9W',
#  'BMW FINANCE NV 2017 2.1% 16/05/22 REG.S - GROSS PRICE': '849D6L',
#  'BMW FINANCE NV 2017 3/4% 12/07/24 REG.S - GROSS PRICE': '841N0E',
#  'BMW FINANCE NV 2017 4 1/4% 18/10/20 REG.S - GROSS PRICE': '856ZCN',
#  'BMW FINANCE NV 2017 7/8% 03/04/25 REG.S - GROSS PRICE': '846JX6',
#  'BMW FINANCE NV 2017 F/R 11/19 REG.S - GROSS PRICE': '849DAL',
#  'BMW FINANCE NV 2018 1 1/8% 10/01/28 REG.S - GROSS PRICE': '860ZUR',
#  'BMW FINANCE NV 2018 1 1/8% 22/05/26 REG.S - GROSS PRICE': '206EE8',
#  'BMW FINANCE NV 2018 1% 14/11/24 REG.S - GROSS PRICE': '216JJQ',
#  'BMW FINANCE NV 2018 1% 29/08/25 REG.S - GROSS PRICE': '211Z43',
#  'BMW FINANCE NV 2018 1/2% 22/11/22 REG.S - GROSS PRICE': '206EED',
#  'BMW FINANCE NV 2018 1/4% 14/01/22 REG.S - GROSS PRICE': '216JJP',
#  'BMW FINANCE NV 2018 1/8% 29/11/21 REG.S - GROSS PRICE': '211Z44',
#  'BMW FINANCE NV 2018 3/8% 10/07/23 REG.S - GROSS PRICE': '860ZUQ',
#  'BMW FINANCE NV 2018 4.4% 20/09/21 REG.S - GROSS PRICE': '2129NY',
#  'BMW FINANCE NV 2018 F/R 01/20 REG.S - GROSS PRICE': '862AVU',
#  'BMW FINANCE NV 2018 F/R 02/20 REG.S - GROSS PRICE': '862Z5E',
#  'BMW FINANCE NV 2018 F/R 02/20 REG.S - GROSS PRICE.1': '863A5J',
#  'BMW FINANCE NV 2018 F/R 02/20 T EARLY - GROSS PRICE': '863EH4',
#  'BMW FINANCE NV 2018 F/R 03/20 REG.S - GROSS PRICE': '201XML',
#  'BMW FINANCE NV 2018 F/R 03/20 REG.S - GROSS PRICE.1': '203MFP',
#  'BMW FINANCE NV 2018 F/R 06/20 REG.S - GROSS PRICE': '208JDC',
#  'BMW FINANCE NV 2018 F/R 06/20 REG.S - GROSS PRICE.1': '207RHF',
#  'BMW FINANCE NV 2018 F/R 08/20 REG.S - GROSS PRICE': '2101A2',
#  'BMW FINANCE NV 2018 F/R 09/20 REG.S - GROSS PRICE': '213EUN',
#  'BMW FINANCE NV 2018 F/R 10/20 REG.S - GROSS PRICE': '214T9E',
#  'BMW FINANCE NV 2018 F/R 11/20 REG.S - GROSS PRICE': '216NP1',
#  'BMW FINANCE NV 2018 F/R 12/19 REG.S - GROSS PRICE': '208V9K',
#  'BMW FINANCE NV 2019 0% 24/03/23 REG.S - GROSS PRICE': '240HW0',
#  'BMW FINANCE NV 2019 1 1/2% 06/02/29 REG.S - GROSS PRICE': '220YXT',
#  'BMW FINANCE NV 2019 1/8% 13/07/22 REG.S - GROSS PRICE': '232KRL',
#  'BMW FINANCE NV 2019 2 1/4% 12/08/22 REG.S - GROSS PRICE': '237NXT',
#  'BMW FINANCE NV 2019 2 1/4% 19/06/23 REG.S - GROSS PRICE': '232ZZT',
#  'BMW FINANCE NV 2019 2.4% 14/08/24 REG.S - GROSS PRICE': '237NXA',
#  'BMW FINANCE NV 2019 2.85% 14/08/29 REG.S - GROSS PRICE': '237NXK',
#  'BMW FINANCE NV 2019 3/4% 13/07/26 REG.S - GROSS PRICE': '232KRP',
#  'BMW FINANCE NV 2019 3/8% 24/09/27 REG.S - GROSS PRICE': '240HW1',
#  'BMW FINANCE NV 2019 5/8% 06/10/23 REG.S - GROSS PRICE': '220YXP',
#  'BMW FINANCE NV 2019 F/R 01/21 REG.S - GROSS PRICE': '219UPN',
#  'BMW FINANCE NV 2019 F/R 02/21 REG.S - GROSS PRICE': '227XMQ',
#  'BMW FINANCE NV 2019 F/R 06/23 REG.S - GROSS PRICE': '232RXQ',
#  'BMW FINANCE NV 2019 F/R 08/20 REG.S - GROSS PRICE': '237UZW',
#  'BMW FINANCE NV 2019 F/R 08/21 REG.S - GROSS PRICE': '237QH1',
#  'BMW FINANCE NV 2019 F/R 08/22 REG.S - GROSS PRICE': '237YRG',
#  'BMW FINANCE NV 2019 F/R 08/22 REG.S - GROSS PRICE.1': '237NXH',
#  'BMW FINANCE NV 2019 F/R 12/20 REG.S - GROSS PRICE': '227XLE',
#  'BMW FINANCE NV 2020 0% 14/04/23 REG.S - GROSS PRICE': '248MJ7',
#  'BMW FINANCE NV 2020 1 1/4% 24/08/21 REG.S - GROSS PRICE': '604M0K',
#  'BMW FINANCE NV 2020 2.07% 14/02/30 REG.S - GROSS PRICE': '252DZZ',
#  'BMW FINANCE NV 2020 2.8% 11/08/23 REG.S - GROSS PRICE': '615FNP',
#  'BMW FINANCE NV 2020 3.35% 17/04/30 REG.S - GROSS PRICE': '604EYH',
#  'BMW FINANCE NV 2020 3/8% 14/01/27 REG.S - GROSS PRICE': '248MFD',
#  'BMW FINANCE NV 2020 7/8% 14/01/32 REG.S - GROSS PRICE': '248MJ6',
#  'BMW FINANCE NV 2020 F/R 02/22 REG.S - GROSS PRICE': '252FWQ',
#  'BMW FINANCE NV 2020 F/R 04/23 REG.S - GROSS PRICE': '604M4J',
#  'BMW FINANCE NV 2020 F/R 06/22 REG.S - GROSS PRICE': '616G17',
#  'BMW FINANCE NV 2020 F/R 10/23 REG.S - GROSS PRICE': '620AVL',
#  'BMW FINANCE NV 2021 0% 11/01/26 REG.S - GROSS PRICE': '628W3F',
#  'BMW FINANCE NV 2021 0.2% 11/01/33 REG.S - GROSS PRICE': '628W5Y',
#  'BMW FINANCE NV 2022 1% 22/05/28 REG.S - GROSS PRICE': '902Z1Z',
#  'BMW FINANCE NV 2022 1/2% 22/02/25 REG.S - GROSS PRICE': '902Z1Y',
#  'BMW FINANCE NV 2023 3 1/2% 06/04/25 REG.S - GROSS PRICE': '976MW5',
#  'BMW FINANCE NV 2023 3 1/2% 19/10/24 REG.S - GROSS PRICE': '9768VH',
#  'BMW FINANCE NV 2023 3 1/4% 22/07/30 REG.S - GROSS PRICE': '979HDX',
#  'BMW FINANCE NV 2023 3 1/4% 22/11/26 REG.S - GROSS PRICE': '979HDY',
#  'BMW FINANCE NV 2023 3 5/8% 21/10/24 REG.S - GROSS PRICE': '977J15',
#  'BMW FINANCE NV 2023 3 5/8% 22/05/35 REG.S - GROSS PRICE': '979HDZ',
#  'BMW FINANCE NV 2023 F/R 07/25 REG.S - GROSS PRICE': '985CW7',
#  'BMW FINANCE NV 2023 F/R 12/24 REG.S - GROSS PRICE': '980NJQ',
#  'DEUTSCHE TELEKOM AG 2017 2.7% 19/07/27 REG.S - GROSS PRICE': '851U2L',
#  'DEUTSCHE TELEKOM AG 2018 2 1/4% 24/07/23 REG.S - GROSS PRICE': '2098Z8',
#  'DEUTSCHE TELEKOM AG 2018 2.97% 10/04/28 REG.S - GROSS PRICE': '204JEJ',
#  'DEUTSCHE TELEKOM AG 2018 3.85% 15/03/28 REG.S - GROSS PRICE': '202K7J',
#  'DEUTSCHE TELEKOM AG 2018 4.6% 22/08/33 REG.S - GROSS PRICE': '211QE0',
#  'DEUTSCHE TELEKOM AG 2019 1 3/4% 09/12/49 REG.S - GROSS PRICE': '245QRX',
#  'DEUTSCHE TELEKOM AG 2019 1 3/4% 25/03/31 REG.S - GROSS PRICE': '223KX0',
#  'DEUTSCHE TELEKOM AG 2019 1 3/8% 05/07/34 REG.S - GROSS PRICE': '234AXM',
#  'DEUTSCHE TELEKOM AG 2019 1/2% 05/07/27 REG.S - GROSS PRICE': '234AXN',
#  'DEUTSCHE TELEKOM AG 2019 2 1/4% 29/03/39 REG.S - GROSS PRICE': '224EGM',
#  'DEUTSCHE TELEKOM AG 2019 3 1/2% 06/09/39 REG.S - GROSS PRICE': '239FD7',
#  'DEUTSCHE TELEKOM AG 2019 3 1/8% 06/02/34 REG.S - GROSS PRICE': '220Y3P',
#  'DEUTSCHE TELEKOM AG 2019 4 1/8% 23/07/49 REG.S - GROSS PRICE': '235H48',
#  'DEUTSCHE TELEKOM AG 2019 7/8% 25/03/26 REG.S - GROSS PRICE': '223KXY',
#  'DEUTSCHE TELEKOM AG 2020 2 1/4% 29/03/39 T EARLY - GROSS PRICE': '250AW1',
#  'DEUTSCHE TELEKOM AG 2020 3 5/8% 21/01/50 REG.S - GROSS PRICE': '249CRR',
#  'DEUTSCHE TELEKOM AG 2021 1 3/4% 09/12/49 T EARLY - GROSS PRICE': '646V3X',
#  'DEUTSCHE TELEKOM AG 2021 3 1/2% 15/04/41 REG.S - GROSS PRICE': '640HPN',
#  'DT.TKOM.INTL.FIN. 2000 G/R 15/06/30 S - GROSS PRICE': '216511',
#  'DT.TKOM.INTL.FIN. 2000 G/R 15/06/30 S - GROSS PRICE.1': '216514',
#  'DT.TKOM.INTL.FIN. 2002 7 3/8% 04/12/19 REG.S - GROSS PRICE': '23124L',
#  'DT.TKOM.INTL.FIN. 2002 9 1/4% 01/06/32 3 - GROSS PRICE': '21378U',
#  'DT.TKOM.INTL.FIN. 2003 7 1/2% 24/01/33 - GROSS PRICE': '23548P',
#  'DT.TKOM.INTL.FIN. 2008 5.851% 17/03/23 REG.S - GROSS PRICE': '2055QV',
#  'DT.TKOM.INTL.FIN. 2008 8 7/8% 27/11/28 REG.S - GROSS PRICE': '2528E9',
#  'DT.TKOM.INTL.FIN. 2009 5 3/8% 27/07/21 REG.S - GROSS PRICE': '3891N1',
#  'DT.TKOM.INTL.FIN. 2009 6 1/2% 08/04/22 REG.S - GROSS PRICE': '3778QU',
#  'DT.TKOM.INTL.FIN. 2010 4 1/2% 28/10/30 REG.S - GROSS PRICE': '6109XT',
#  'DT.TKOM.INTL.FIN. 2010 4 1/4% 13/07/22 REG.S - GROSS PRICE': '5688JF',
#  'DT.TKOM.INTL.FIN. 2010 4 1/4% 16/03/20 REG.S - GROSS PRICE': '5586U5',
#  'DT.TKOM.INTL.FIN. 2010 4 7/8% 22/04/25 REG.S - GROSS PRICE': '5613V5',
#  'DT.TKOM.INTL.FIN. 2010 4.628% 25/01/22 - GROSS PRICE': '6037K3',
#  'DT.TKOM.INTL.FIN. 2012 2 3/4% 24/10/24 REG.S - GROSS PRICE': '8050Z1',
#  'DT.TKOM.INTL.FIN. 2012 2% 30/10/19 REG.S - GROSS PRICE': '8070QG',
#  'DT.TKOM.INTL.FIN. 2012 3% 21/12/32 REG.S - GROSS PRICE': '8209NY',
#  'DT.TKOM.INTL.FIN. 2012 4 7/8% 06/03/42 REG.S - GROSS PRICE': '7812L4',
#  'DT.TKOM.INTL.FIN. 2012 4.3% 20/01/27 - GROSS PRICE': '7471N6',
#  'DT.TKOM.INTL.FIN. 2013 2 1/8% 18/01/21 REG.S - GROSS PRICE': '8283Z7',
#  'DT.TKOM.INTL.FIN. 2013 3 1/2% 15/07/33 - GROSS PRICE': '783FPV',
#  'DT.TKOM.INTL.FIN. 2013 3 1/4% 17/01/28 REG.S - GROSS PRICE': '8283Z8',
#  'DT.TKOM.INTL.FIN. 2013 3.55% 11/02/33 - GROSS PRICE': '8375YT',
#  'DT.TKOM.INTL.FIN. 2013 3.55% 17/01/33 - GROSS PRICE': '8303ZF',
#  'DT.TKOM.INTL.FIN. 2013 3.9% 22/04/33 REG.S - GROSS PRICE': '8623ZZ',
#  'DT.TKOM.INTL.FIN. 2016 1 1/2% 03/04/28 REG.S - GROSS PRICE': '827NC3',
#  'DT.TKOM.INTL.FIN. 2016 1 1/4% 06/10/23 REG.S - GROSS PRICE': '836RZU',
#  'DT.TKOM.INTL.FIN. 2016 1.95% 19/09/21 REG.S - GROSS PRICE': '835VGT',
#  'DT.TKOM.INTL.FIN. 2016 1/4% 19/04/21 REG.S - GROSS PRICE': '828T1J',
#  'DT.TKOM.INTL.FIN. 2016 2.485% 19/09/23 EARLY - GROSS PRICE': '835VGU',
#  'DT.TKOM.INTL.FIN. 2016 5/8% 03/04/23 REG.S - GROSS PRICE': '827NC2',
#  'DT.TKOM.INTL.FIN. 2016 F/R 04/20 Q - GROSS PRICE': '841FGT',
#  'DT.TKOM.INTL.FIN. 2016 F/R 04/20 REG.S - GROSS PRICE': '827NC9',
#  'DT.TKOM.INTL.FIN. 2017 1 1/8% 22/05/26 REG.S - GROSS PRICE': '849A0F',
#  'DT.TKOM.INTL.FIN. 2017 1 3/8% 30/01/27 REG.S - GROSS PRICE': '842RE0',
#  'DT.TKOM.INTL.FIN. 2017 2 1/4% 13/04/29 REG.S - GROSS PRICE': '846V6R',
#  'DT.TKOM.INTL.FIN. 2017 2.225% 17/01/20 REG.S - GROSS PRICE': '841UG2',
#  'DT.TKOM.INTL.FIN. 2017 2.82% 19/01/22 EARLY - GROSS PRICE': '841UGX',
#  'DT.TKOM.INTL.FIN. 2017 2.95% 19/04/27 REG.S - GROSS PRICE': '847HFX',
#  'DT.TKOM.INTL.FIN. 2017 3.6% 19/01/27 REG.S - GROSS PRICE': '841UG3',
#  'DT.TKOM.INTL.FIN. 2017 3/8% 30/10/21 REG.S - GROSS PRICE': '842REU',
#  'DT.TKOM.INTL.FIN. 2017 5/8% 13/12/24 REG.S - GROSS PRICE': '859V73',
#  'DT.TKOM.INTL.FIN. 2017 7/8% 30/01/24 REG.S - GROSS PRICE': '842RE3',
#  'DT.TKOM.INTL.FIN. 2017 F/R 01/20 REG.S - GROSS PRICE': '841UHG',
#  'DT.TKOM.INTL.FIN. 2018 1 3/8% 01/12/25 REG.S - GROSS PRICE': '206UEX',
#  'DT.TKOM.INTL.FIN. 2018 2 1/2% 10/10/25 REG.S - GROSS PRICE': '214GAN',
#  'DT.TKOM.INTL.FIN. 2018 2% 01/12/29 REG.S - GROSS PRICE': '206UEQ',
#  'DT.TKOM.INTL.FIN. 2018 2.2% 25/07/33 REG.S - GROSS PRICE': '2099ZL',
#  'DT.TKOM.INTL.FIN. 2018 4 3/4% 21/06/38 REG.S - GROSS PRICE': '208FEV',
#  'DT.TKOM.INTL.FIN. 2018 4 3/8% 21/06/28 REG.S - GROSS PRICE': '208FEU',
#  'DT.TKOM.INTL.FIN. 2018 5/8% 01/12/22 REG.S - GROSS PRICE': '207H2Z',
#  'DT.TKOM.INTL.FIN. 2018 F/R 01/20 REG.S - GROSS PRICE': '862FK7',
#  'DT.TKOM.INTL.FIN. 2018 F/R 12/22 REG.S - GROSS PRICE': '206UEV',
#  'E ON SE 2017 1 5/8% 22/05/29 REG.S - GROSS PRICE': '848Y6V',
#  'E ON SE 2017 3/8% 23/08/21 EARLY - GROSS PRICE': '848Y6X',
#  'E ON SE 2017 7/8% 22/05/24 REG.S - GROSS PRICE': '848Y6W',
#  'E ON SE 2019 0% 24/10/22 REG.S - GROSS PRICE': '242MKW',
#  'E ON SE 2019 0% 28/08/24 REG.S - GROSS PRICE': '238PXP',
#  'E ON SE 2019 0% 29/09/22 REG.S - GROSS PRICE': '246ADU',
#  'E ON SE 2019 0.35% 28/02/30 REG.S - GROSS PRICE': '238PXC',
#  'E ON SE 2019 1/4% 24/10/26 REG.S - GROSS PRICE': '242MLD',
#  'E ON SE 2019 3 1/2% 26/10/37 - GROSS PRICE': '620EV6',
#  'E ON SE 2019 5/8% 07/11/31 REG.S - GROSS PRICE': '243PCA',
#  'E ON SE 2020 0% 18/12/23 REG.S - GROSS PRICE': '248P9T',
#  'E ON SE 2020 1% 07/10/25 REG.S - GROSS PRICE': '603EET',
#  'E ON SE 2020 3/4% 18/12/30 REG.S - GROSS PRICE': '248QAJ',
#  'E ON SE 2020 3/4% 20/02/28 REG.S - GROSS PRICE': '607CA5',
#  'E ON SE 2020 3/8% 20/04/23 REG.S - GROSS PRICE': '607CA6',
#  'E ON SE 2020 3/8% 29/09/27 REG.S - GROSS PRICE': '248P9U',
#  'E ON SE 2020 7/8% 20/08/31 REG.S - GROSS PRICE': '607CA7',
#  'E ON SE 2021 0.1% 19/12/28 REG.S - GROSS PRICE': '6295ZJ',
#  'E ON SE 2021 0.6% 01/10/32 REG.S - GROSS PRICE': '638M44',
#  'E ON SE 2022 1 5/8% 29/03/31 REG.S - GROSS PRICE': '910F4T',
#  'E ON SE 2022 1/8% 18/01/26 REG.S - GROSS PRICE': '666P36',
#  'E ON SE 2022 2 7/8% 26/08/28 REG.S - GROSS PRICE': '949GXF',
#  'E ON SE 2022 7/8% 08/01/25 REG.S - GROSS PRICE': '910F4H',
#  'E ON SE 2022 7/8% 18/10/34 REG.S - GROSS PRICE': '666P37',
#  'E ON SE 2023 3 1/2% 12/01/28 REG.S - GROSS PRICE': '9659AJ',
#  'E ON SE 2023 3 7/8% 12/01/35 REG.S - GROSS PRICE': '9659AL',
#  'ENBW ENGE.BA.WUERT. 2014 3.625%(F/R)04/76 EARLY - GROSS PRICE': '791G5Y',
#  'ENBW ENGE.BA.WUERT. 2016 3.375%(F/R)04/77 EARLY - GROSS PRICE': '836P83',
#  'ENBW ENGE.BA.WUERT. 2016 5.125%(F/R)04/77 EARLY - GROSS PRICE': '836K64',
#  'ENBW ENGE.BA.WUERT. 2019 1.125%(F/R)11/79 REG.S - GROSS PRICE': '236GF6',
#  'ENBW ENGE.BA.WUERT. 2019 1.625%(F/R)08/79 REG.S - GROSS PRICE': '236GF9',
#  'ENBW ENGE.BA.WUERT. 2020 1.875%(F/R)06/80 REG.S - GROSS PRICE': '610W5G',
#  'ENBW ENGE.BA.WUERT. 2021 1.375%(F/R)08/81 REG.S - GROSS PRICE': '653J02',
#  'ENBW ENGE.BA.WUERT. 2021 2.125%(F/R)08/81 REG.S - GROSS PRICE': '655NCP',
#  'ENBW INTL.FINANCE 2004 4 7/8% 16/01/25 REG.S - GROSS PRICE': '478517',
#  'ENBW INTL.FINANCE 2008 3.88% 16/12/38 REG.S - GROSS PRICE': '5989VD',
#  'ENBW INTL.FINANCE 2009 6 1/8% 07/07/39 REG.S - GROSS PRICE': '3878R6',
#  'ENBW INTL.FINANCE 2014 2 1/2% 04/06/26 REG.S - GROSS PRICE': '794GNW',
#  'ENBW INTL.FINANCE 2014 2 7/8% 13/06/34 19 - GROSS PRICE': '794XUZ',
#  'ENBW INTL.FINANCE 2014 3.08% 16/06/39 18 - GROSS PRICE': '794Q4D',
#  'ENBW INTL.FINANCE 2018 1 7/8% 31/10/33 REG.S - GROSS PRICE': '215K7D',
#  'ENBW INTL.FINANCE 2019 2.08% 21/01/40 REG.S - GROSS PRICE': '219Y2E',
#  'ENBW INTL.FINANCE 2020 1/4% 19/10/30 REG.S - GROSS PRICE': '621JA3',
#  'ENBW INTL.FINANCE 2020 5/8% 17/04/25 REG.S - GROSS PRICE': '603TFE',
#  'ENBW INTL.FINANCE 2021 1/2% 01/03/33 REG.S - GROSS PRICE': '634U03',
#  'ENBW INTL.FINANCE 2021 1/8% 01/03/28 REG.S - GROSS PRICE': '634U01',
#  'ENBW INTL.FINANCE 2022 0% 14/02/34 EARLY - GROSS PRICE': '669JY7',
#  'ENBW INTL.FINANCE 2022 0% 14/03/29 EARLY - GROSS PRICE': '669JYX',
#  'ENBW INTL.FINANCE 2022 3 5/8% 22/11/26 REG.S - GROSS PRICE': '9587MM',
#  'ENBW INTL.FINANCE 2022 4.049% 22/11/29 REG.S - GROSS PRICE': '9587L1',
#  'ENBW INTL.FINANCE 2023 3 1/2% 24/07/28 REG.S - GROSS PRICE': '968XD1',
#  'ENBW INTL.FINANCE 2023 4% 24/01/35 REG.S - GROSS PRICE': '9679CN',
#  'INNOGY FINANCE BV 2013 1 7/8% 30/01/20 REG.S - GROSS PRICE': '83067Y',
#  'INNOGY FINANCE BV 2019 3/4% 31/07/23 EARLY - GROSS PRICE': '220MC9',
#  'LANXESS AG 2012 2 5/8% 21/11/22 REG.S - GROSS PRICE': '8116HA',
#  'LANXESS AG 2012 3 1/2% 05/04/22 6 - GROSS PRICE': '7857KN',
#  'LANXESS AG 2012 3.95% 05/04/27 REG.S - GROSS PRICE': '7857NF',
#  'LANXESS AG 2016 1% 07/10/26 REG.S - GROSS PRICE': '836R40',
#  'LANXESS AG 2016 1/4% 07/10/21 EARLY - GROSS PRICE': '836R4Z',
#  'LANXESS AG 2016 4.5%(F/R) 12/76 EARLY - GROSS PRICE': '839RNV',
#  'LANXESS AG 2018 1 1/8% 16/05/25 REG.S - GROSS PRICE': '205ZFY',
#  'LANXESS AG 2021 0% 08/09/27 REG.S - GROSS PRICE': '654F5Q',
#  'LANXESS AG 2021 5/8% 01/12/29 REG.S - GROSS PRICE': '662P28',
#  'LANXESS AG 2022 1 3/4% 22/03/28 REG.S - GROSS PRICE': '909H1D',
#  'METRO AG 2012 4% 09/08/27 REG.S - GROSS PRICE': '8182FH',
#  'METRO AG 2012 4% 10/07/24 25 - GROSS PRICE': '8005PX',
#  'METRO AG 2012 4% 11/07/22 26 - GROSS PRICE': '8004MJ',
#  'METRO AG 2012 4.05% 20/01/20 19 - GROSS PRICE': '7449TF',
#  'METRO AG 2014 1 3/8% 28/10/21 REG.S - GROSS PRICE': '799VNC',
#  'METRO AG 2015 1 1/2% 19/03/25 REG.S - GROSS PRICE': '807TAD',
#  'METRO AG 2018 1 1/8% 06/03/23 REG.S - GROSS PRICE': '201U9K',
#  'SIEMENS ENERGY FIN 2023 4 1/4% 05/04/29 REG.S - GROSS PRICE': '976C8H',
#  'SIEMENS ENERGY FIN 2023 4% 05/04/26 REG.S - GROSS PRICE': '976EKM',
#  'SIEMENS ENERGY FIN CV 5 5/8% 14/09/25 REG.S - GROSS PRICE': '950VFT',
#  'SIEMENS FINMCH 2006 6 1/8% 17/08/26 REG.S - GROSS PRICE': '78882V',
#  'SIEMENS FINMCH 2012 1 1/2% 10/03/20 - GROSS PRICE': '8386LT',
#  'SIEMENS FINMCH 2012 2 3/4% 10/09/25 REG.S - GROSS PRICE': '8386LP',
#  'SIEMENS FINMCH 2012 3 3/4% 10/09/42 REG.S - GROSS PRICE': '8386LU',
#  'SIEMENS FINMCH 2013 1 3/4% 12/03/21 REG.S - GROSS PRICE': '84528Y',
#  'SIEMENS FINMCH 2013 2 7/8% 10/03/28 REG.S - GROSS PRICE': '84529A',
#  'SIEMENS FINMCH 2013 3 1/2% 20/03/28 S - GROSS PRICE': '8490JA',
#  'SIEMENS FINMCH 2015 2.15% 27/05/20 REG.S - GROSS PRICE': '811TW0',
#  'SIEMENS FINMCH 2015 2.9% 27/05/22 REG.S - GROSS PRICE': '811TW9',
#  'SIEMENS FINMCH 2015 3 1/4% 27/05/25 REG.S - GROSS PRICE': '811TXC',
#  'SIEMENS FINMCH 2015 4.4% 27/05/45 REG.S - GROSS PRICE': '811TXE',
#  'SIEMENS FINMCH 2016 1.7% 15/09/21 REG.S - GROSS PRICE': '835K47',
#  'SIEMENS FINMCH 2016 2% 15/09/23 REG.S - GROSS PRICE': '835K45',
#  'SIEMENS FINMCH 2016 2.35% 15/10/26 REG.S - GROSS PRICE': '835K48',
#  'SIEMENS FINMCH 2016 3.3% 15/09/46 REG.S - GROSS PRICE': '835K46',
#  'SIEMENS FINMCH 2017 2.2% 16/03/20 REG.S - GROSS PRICE': '845G2Y',
#  'SIEMENS FINMCH 2017 2.7% 16/03/22 REG.S - GROSS PRICE': '845G2L',
#  'SIEMENS FINMCH 2017 3 1/8% 16/03/24 REG.S - GROSS PRICE': '845G2T',
#  'SIEMENS FINMCH 2017 3.4% 16/03/27 REG.S - GROSS PRICE': '845G28',
#  'SIEMENS FINMCH 2017 4.2% 16/03/47 REG.S - GROSS PRICE': '845G3E',
#  'SIEMENS FINMCH 2017 F/R 03/20 REG.S - GROSS PRICE': '845G3M',
#  'SIEMENS FINMCH 2017 F/R 03/22 REG.S - GROSS PRICE': '845G2M',
#  'SIEMENS FINMCH 2018 1 3/8% 06/09/30 REG.S - GROSS PRICE': '212CZN',
#  'SIEMENS FINMCH 2018 1% 06/09/27 REG.S - GROSS PRICE': '212CYN',
#  'SIEMENS FINMCH 2018 3/8% 06/09/23 REG.S - GROSS PRICE': '212CYM',
#  'SIEMENS FINMCH 2019 0% 05/09/21 REG.S - GROSS PRICE': '238YZD',
#  'SIEMENS FINMCH 2019 0% 05/09/24 REG.S - GROSS PRICE': '238Y1P',
#  'SIEMENS FINMCH 2019 0.3% 28/02/24 REG.S - GROSS PRICE': '221Z4F',
#  'SIEMENS FINMCH 2019 0.9% 28/02/28 REG.S - GROSS PRICE': '221Z4L',
#  'SIEMENS FINMCH 2019 1 1/4% 28/02/31 REG.S - GROSS PRICE': '221Z4N',
#  'SIEMENS FINMCH 2019 1 3/4% 28/02/39 REG.S - GROSS PRICE': '221Z8Z',
#  'SIEMENS FINMCH 2019 1/2% 05/09/34 REG.S - GROSS PRICE': '238Y1E',
#  'SIEMENS FINMCH 2019 1/8% 05/09/29 REG.S - GROSS PRICE': '238Y1F',
#  'SIEMENS FINMCH 2019 F/R 12/21 REG.S - GROSS PRICE': '246PCT',
#  'SIEMENS FINMCH 2020 0% 20/02/23 REG.S - GROSS PRICE': '2514FZ',
#  'SIEMENS FINMCH 2020 0% 20/02/26 REG.S - GROSS PRICE': '2515AQ',
#  'SIEMENS FINMCH 2020 1% 20/02/25 REG.S - GROSS PRICE': '25141Y',
#  'SIEMENS FINMCH 2020 1/2% 20/02/32 REG.S - GROSS PRICE': '2515AX',
#  'SIEMENS FINMCH 2020 1/4% 05/06/24 REG.S - GROSS PRICE': '608H20',
#  'SIEMENS FINMCH 2020 1/4% 20/02/29 REG.S - GROSS PRICE': '2515AR',
#  'SIEMENS FINMCH 2020 1/8% 05/06/22 REG.S - GROSS PRICE': '608H2V',
#  'SIEMENS FINMCH 2020 3/8% 05/06/26 REG.S - GROSS PRICE': '608H2Z',
#  'SIEMENS FINMCH 2020 7/8% 05/06/23 REG.S - GROSS PRICE': '608H24',
#  'SIEMENS FINMCH 2021 0.4% 11/03/23 REG.S - GROSS PRICE': '635ZMQ',
#  'SIEMENS FINMCH 2021 0.65% 11/03/24 REG.S - GROSS PRICE': '635ZM2',
#  'SIEMENS FINMCH 2021 1.2% 11/03/26 REG.S - GROSS PRICE': '635ZNV',
#  'SIEMENS FINMCH 2021 1.7% 11/03/28 REG.S - GROSS PRICE': '635ZM1',
#  'SIEMENS FINMCH 2021 2 7/8% 11/03/41 REG.S - GROSS PRICE': '635ZN1',
#  'SIEMENS FINMCH 2021 2.15% 11/03/31 REG.S - GROSS PRICE': '635ZNJ',
#  'SIEMENS FINMCH 2021 F/R 03/24 REG.S - GROSS PRICE': '635ZN3',
#  'SIEMENS FINMCH 2022 1 1/4% 25/02/35 REG.S - GROSS PRICE': '9026ZY',
#  'SIEMENS FINMCH 2022 1% 25/02/30 REG.S - GROSS PRICE': '90260A',
#  'SIEMENS FINMCH 2022 2 1/2% 08/09/27 REG.S - GROSS PRICE': '9498UX',
#  'SIEMENS FINMCH 2022 2 1/4% 10/03/25 REG.S - GROSS PRICE': '9498M4',
#  'SIEMENS FINMCH 2022 2 3/4% 09/09/30 REG.S - GROSS PRICE': '9498M5',
#  'SIEMENS FINMCH 2022 3% 08/09/33 REG.S - GROSS PRICE': '9498WP',
#  'SIEMENS FINMCH 2022 5/8% 25/02/27 REG.S - GROSS PRICE': '9026ZP',
#  'SIEMENS FINMCH 2023 3 1/2% 24/02/36 REG.S - GROSS PRICE': '970E9V',
#  'SIEMENS FINMCH 2023 3 3/8% 24/08/31 REG.S - GROSS PRICE': '970E9R',
#  'SIEMENS FINMCH 2023 3 5/8% 24/02/43 REG.S - GROSS PRICE': '970E9T',
#  'SUEDZUCKER INFN BV 2005 5.25%(F/R) PERP. REG.S - GROSS PRICE': '55848N',
#  'SUEDZUCKER INFN BV 2016 1 1/4% 29/11/23 REG.S - GROSS PRICE': '839KZR',
#  'SUEDZUCKER INFN BV 2017 1% 28/11/25 REG.S - GROSS PRICE': '859JTX',
#  'SUEDZUCKER INFN BV 2022 5 1/8% 31/10/27 REG.S - GROSS PRICE': '957KRL',
#  'VOLKSWAGEN FNSR. 2015 3/4% 14/10/21 REG.S - GROSS PRICE': '809FQA',
#  'VOLKSWAGEN FNSR. 2018 1 3/8% 16/10/23 REG.S - GROSS PRICE': '214P2W',
#  'VOLKSWAGEN FNSR. 2018 1/4% 16/10/20 REG.S - GROSS PRICE': '214P1N',
#  'VOLKSWAGEN FNSR. 2018 2 1/4% 16/10/26 REG.S - GROSS PRICE': '214P02',
#  'VOLKSWAGEN FNSR. 2018 3/8% 12/04/21 REG.S - GROSS PRICE': '204ATV',
#  'VOLKSWAGEN FNSR. 2018 7/8% 12/04/23 REG.S - GROSS PRICE': '204AUM',
#  'VOLKSWAGEN FNSR. 2018 F/R 07/20 REG.S - GROSS PRICE': '209RXK',
#  'VOLKSWAGEN FNSR. 2018 F/R 07/20 REG.S - GROSS PRICE.1': '209U5E',
#  'VOLKSWAGEN FNSR. 2018 F/R 10/19 REG.S - GROSS PRICE': '204ATU',
#  'VOLKSWAGEN FNSR. 2019 1 1/2% 01/10/24 REG.S - GROSS PRICE': '224GPN',
#  'VOLKSWAGEN FNSR. 2019 2 1/4% 01/10/27 REG.S - GROSS PRICE': '224HUJ',
#  'VOLKSWAGEN FNSR. 2019 5/8% 01/04/22 REG.S - GROSS PRICE': '224GNZ',
#  'VOLKSWAGEN FNSR. 2019 F/R 02/21 REG.S - GROSS PRICE': '221MN5',
#  'VOLKSWAGEN FNSR. 2020 0.16% 16/09/21 REG.S - GROSS PRICE': '618KRN',
#  'VOLKSWAGEN FNSR. 2020 2 1/2% 06/04/23 REG.S - GROSS PRICE': '603EEJ',
#  'VOLKSWAGEN FNSR. 2020 3 3/8% 06/04/28 REG.S - GROSS PRICE': '603AXD',
#  'VOLKSWAGEN FNSR. 2020 3% 06/04/25 REG.S - GROSS PRICE': '603AXG',
#  'VOLKSWAGEN FNSR. 2020 F/R 09/21 REG.S - GROSS PRICE': '618K6R',
#  'VOLKSWAGEN FNSR. 2021 0% 12/02/25 REG.S - GROSS PRICE': '651PGT',
#  'VOLKSWAGEN FNSR. 2021 1/8% 12/02/27 REG.S - GROSS PRICE': '651PGR',
#  'VOLKSWAGEN FNSR. 2021 3/8% 12/02/30 REG.S - GROSS PRICE': '651PGV',
#  'VOLKSWAGEN FNSR. 2021 F/R 04/23 REG.S - GROSS PRICE': '6386YQ',
#  'VOLKSWAGEN FNSR. 2022 1/4% 31/01/25 REG.S - GROSS PRICE': '668CN4',
#  'VOLKSWAGEN FNSR. 2022 7/8% 31/01/28 REG.S - GROSS PRICE': '668CN5',
#  'VOLKSWAGEN FNSR. 2023 F/R 04/24 REG.S - GROSS PRICE': '965X4G',
#  'VW INTL FIN NV 2010 4% 12/08/20 REG.S - GROSS PRICE': '5716Q7',
#  'VW INTL FIN NV 2013 2% 14/01/20 REG.S - GROSS PRICE': '82647Z',
#  'VW INTL FIN NV 2013 2% 26/03/21 REG.S - GROSS PRICE': '8526YM',
#  'VW INTL FIN NV 2013 3 1/2% 02/04/43 REG.S - GROSS PRICE': '8538NG',
#  'VW INTL FIN NV 2013 3.3% 22/03/33 REG.S - GROSS PRICE': '8512ZV',
#  'VW INTL FIN NV 2013 5.125%(F/R)PERP. REG.S - GROSS PRICE': '784TED',
#  'VW INTL FIN NV 2014 3% 01/07/39 REG.S - GROSS PRICE': '795H63',
#  'VW INTL FIN NV 2014 3% 11/04/29 REG.S - GROSS PRICE': '792F3Q',
#  'VW INTL FIN NV 2014 3.4% 30/01/34 REG.S - GROSS PRICE': '789PLC',
#  'VW INTL FIN NV 2014 3.75%(F/R) PERP. EARLY - GROSS PRICE': '791NQU',
#  'VW INTL FIN NV 2014 4.625%(F/R)PERP. REG.S - GROSS PRICE': '791NZH',
#  'VW INTL FIN NV 2015 1 5/8% 16/01/30 REG.S - GROSS PRICE': '803NN9',
#  'VW INTL FIN NV 2015 1/2% 20/02/20 - GROSS PRICE': '804XTV',
#  'VW INTL FIN NV 2015 2.5%(F/R) PERP. EARLY - GROSS PRICE': '808D9J',
#  'VW INTL FIN NV 2015 3.5%(F/R) PERP. REG.S - GROSS PRICE': '808D9K',
#  'VW INTL FIN NV 2015 7/8% 16/01/23 REG.S - GROSS PRICE': '803NPD',
#  'VW INTL FIN NV 2017 1 1/8% 02/10/23 REG.S - GROSS PRICE': '846ERM',
#  'VW INTL FIN NV 2017 1 7/8% 30/03/27 REG.S - GROSS PRICE': '846ERT',
#  'VW INTL FIN NV 2017 1/2% 30/03/21 REG.S - GROSS PRICE': '846EQR',
#  'VW INTL FIN NV 2017 2.7%(F/R) PERP. EARLY - GROSS PRICE': '850JUH',
#  'VW INTL FIN NV 2017 3.875%(F/R)PERP. REG.S - GROSS PRICE': '850JU7',
#  'VW INTL FIN NV 2018 2 5/8% 16/11/27 REG.S - GROSS PRICE': '216NPP',
#  'VW INTL FIN NV 2018 3 1/4% 18/11/30 REG.S - GROSS PRICE': '216NPQ',
#  'VW INTL FIN NV 2018 3 3/8% 16/11/26 REG.S - GROSS PRICE': '216NPT',
#  'VW INTL FIN NV 2018 3.375%(F/R)PERP. REG.S - GROSS PRICE': '208PQL',
#  'VW INTL FIN NV 2018 4 1/8% 16/11/38 REG.S - GROSS PRICE': '216NPR',
#  'VW INTL FIN NV 2018 4 1/8% 17/11/31 REG.S - GROSS PRICE': '216NPU',
#  'VW INTL FIN NV 2018 4 5/8% PERP. REG.S - GROSS PRICE': '208PTJ',
#  'VW INTL FIN NV 2018 F/R 11/24 REG.S - GROSS PRICE': '216NPN',
#  'VW INTL FIN NV 2020 0.05% 10/06/24 REG.S - GROSS PRICE': '626GC0',
#  'VW INTL FIN NV 2020 1 1/4% 23/09/32 REG.S - GROSS PRICE': '619AKZ',
#  'VW INTL FIN NV 2020 3.4% 08/12/23 REG.S - GROSS PRICE': '626NZW',
#  'VW INTL FIN NV 2020 3.5%(F/R) PERP. REG.S - GROSS PRICE': '609MUP',
#  'VW INTL FIN NV 2020 3.875%(F/R)PERP. REG.S - GROSS PRICE': '609MUR',
#  'VW INTL FIN NV 2020 7/8% 22/09/28 REG.S - GROSS PRICE': '619AKG',
#  'VW INTL FIN NV 2021 1 1/2% 21/01/41 REG.S - GROSS PRICE': '630MLZ',
#  'VW INTL FIN NV 2021 2.9% 21/01/24 REG.S - GROSS PRICE': '630K03',
#  'VW INTL FIN NV 2021 F/R 07/22 REG.S - GROSS PRICE': '630GZ8',
#  'VW INTL FIN NV 2022 3 1/8% 28/03/25 REG.S - GROSS PRICE': '930JDP',
#  'VW INTL FIN NV 2022 3 3/4% 28/09/27 REG.S - GROSS PRICE': '930JDW',
#  'VW INTL FIN NV 2022 3.748%(F/R)PERP. REG.S - GROSS PRICE': '9097VQ',
#  'VW INTL FIN NV 2022 4 1/4% 15/02/28 REG.S - GROSS PRICE': '958FP9',
#  'VW INTL FIN NV 2022 4 1/8% 15/11/25 REG.S - GROSS PRICE': '958FQD',
#  'VW INTL FIN NV 2022 4 3/8% 15/05/30 REG.S - GROSS PRICE': '958FP7',
#  'VW INTL FIN NV 2022 4.375%(F/R)PERP. REG.S - GROSS PRICE': '9097VR',
#  'VW INTL FIN NV 2023 3 7/8% 29/03/26 REG.S - GROSS PRICE': '973URD',
#  'VW INTL FIN NV 2023 4 1/4% 29/03/29 REG.S - GROSS PRICE': '973UU7',
#  'VW INTL FIN NV 2023 4.58% 30/05/26 - GROSS PRICE': '979MZH',
#  'VW INTL FIN NV 2023 4.86% 02/06/25 - GROSS PRICE': '9790M1'}

# %%
# Assuming your existing dictionary is named 'dictionary2'
# The structure of dictionary2 should be similar to the one you're appending

new_data = {
    "17015D(GP)": "INNOGY FINANCE BV 2001 6 1/4% 20/04/16 11012",
    "21084E(GP)": "INNOGY FINANCE BV 2002 6 1/8% 26/10/12 11022",
    "25258N(GP)": "INNOGY FINANCE BV 2003 5 1/8% 23/07/18 REG.S",
    "46282M(GP)": "INNOGY FINANCE BV 2004 4 5/8% 23/07/14",
    "2520U6(GP)": "INNOGY FINANCE BV 2008 6 5/8% 31/01/19 REG.S",
    "3855EN(GP)": "INNOGY FINANCE BV 2009 2 1/2% 16/09/11 11093",
    "3697RQ(GP)": "INNOGY FINANCE BV 2009 5% 10/02/15 11091",
    "83067Y(GP)": "INNOGY FINANCE BV 2013 1 7/8% 30/01/20 REG.S",
    "220MC9(GP)": "INNOGY FINANCE BV 2019 3/4% 31/07/23 EARLY"
}

# Appending new data to the existing dictionary
dictionary2.update(new_data)

# The dictionary2 now contains the new entries

# %%
dictionary2
# Out:
# {'Code': 'AAAAAAAAAAAA',
#  'nan': '#ERROR.14',
#  '81542Z': 'BASF SE 2012 2% 05/12/22 12 - GROSS PRICE',
#  '83426Y': 'BASF SE 2013 1 7/8% 04/02/21 13 - GROSS PRICE',
#  '781GAF': 'BASF SE 2013 2 7/8% 16/05/33 REG.S - GROSS PRICE',
#  '7902VA': 'BASF SE 2013 3 1/4% 12/02/43 REG.S - GROSS PRICE',
#  '8511ZH': 'BASF SE 2013 3% 07/02/33 REG.S - GROSS PRICE',
#  '781H04': 'BASF SE 2013 3.675% 28/05/25 REG.S - GROSS PRICE',
#  '781F1M': 'BASF SE 2013 F/R 05/20 Q - GROSS PRICE',
#  '789DV8': 'BASF SE 2014 2 1/2% 22/01/24 REG.S - GROSS PRICE',
#  '826XN1': 'BASF SE 2016 1 1/2% 04/03/31 REG.S - GROSS PRICE',
#  '837PYW': 'BASF SE 2016 2.37% 17/10/31 REG.S - GROSS PRICE',
#  '836RJM': 'BASF SE 2016 7/8% 06/10/23 REG.S - GROSS PRICE',
#  '836F89': 'BASF SE 2016 7/8% 06/10/31 REG.S - GROSS PRICE',
#  '841NGU': 'BASF SE 2017 1 3/4% 11/03/25 REG.S - GROSS PRICE',
#  '858RDK': 'BASF SE 2017 1 5/8% 15/11/37 REG.S - GROSS PRICE',
#  '841NGK': 'BASF SE 2017 1.45% 13/12/32 REG.S - GROSS PRICE',
#  '841VV1': 'BASF SE 2017 2 1/2% 18/01/22 REG.S - GROSS PRICE',
#  '841HM1': 'BASF SE 2017 2.67% 03/01/29 REG.S - GROSS PRICE',
#  '858RDJ': 'BASF SE 2017 7/8% 15/11/27 REG.S - GROSS PRICE',
#  '858RA7': 'BASF SE 2017 F/R 11/19 REG.S - GROSS PRICE',
#  '206G5U': 'BASF SE 2018 1 1/2% 22/05/30 REG.S - GROSS PRICE',
#  '208D0J': 'BASF SE 2018 1 3/8% 21/06/22 REG.S - GROSS PRICE',
#  '210Z9J': 'BASF SE 2018 4% 10/08/33 REG.S - GROSS PRICE',
#  '206H4Y': 'BASF SE 2018 7/8% 22/05/25 REG.S - GROSS PRICE',
#  '222UMF': 'BASF SE 2019 7/8% 07/03/29 REG.S - GROSS PRICE',
#  '608KTX': 'BASF SE 2020 0.101% 05/06/23 REG.S - GROSS PRICE',
#  '608KTY': 'BASF SE 2020 1/4% 05/06/27 REG.S - GROSS PRICE',
#  '908XHH': 'BASF SE 2022 1 1/2% 17/03/31 REG.S - GROSS PRICE',
#  '930KXX': 'BASF SE 2022 3 1/8% 29/06/28 REG.S - GROSS PRICE',
#  '930KX2': 'BASF SE 2022 3 3/4% 29/06/32 REG.S - GROSS PRICE',
#  '908XFT': 'BASF SE 2022 3/4% 17/03/26 REG.S - GROSS PRICE',
#  '971AXQ': 'BASF SE 2023 4 1/2% 08/03/35 REG.S - GROSS PRICE',
#  '971AX0': 'BASF SE 2023 4 1/4% 08/03/32 REG.S - GROSS PRICE',
#  '971AXL': 'BASF SE 2023 4% 08/03/29 REG.S - GROSS PRICE',
#  '8300MY': 'BMW FINANCE NV 2013 2 3/8% 24/01/23 REG.S - GROSS PRICE',
#  '784QE7': 'BMW FINANCE NV 2013 2% 04/09/20 REG.S - GROSS PRICE',
#  '797P2M': 'BMW FINANCE NV 2014 1 1/4% 05/09/22 REG.S - GROSS PRICE',
#  '78810Z': 'BMW FINANCE NV 2014 2 5/8% 17/01/24 REG.S - GROSS PRICE',
#  '818PPQ': 'BMW FINANCE NV 2015 1 3/4% 06/10/20 - GROSS PRICE',
#  '811TY6': 'BMW FINANCE NV 2015 1 7/8% 29/06/20 REG.S - GROSS PRICE',
#  '803R30': 'BMW FINANCE NV 2015 1% 21/01/25 REG.S - GROSS PRICE',
#  '803R3Z': 'BMW FINANCE NV 2015 1/2% 21/01/20 REG.S - GROSS PRICE',
#  '821W6E': 'BMW FINANCE NV 2015 2 3/8% 01/12/21 REG.S - GROSS PRICE',
#  '820KGW': 'BMW FINANCE NV 2015 7/8% 17/11/20 REG.S - GROSS PRICE',
#  '826FT8': 'BMW FINANCE NV 2016 0.239% 22/02/23 REG.S - GROSS PRICE',
#  '824P99': 'BMW FINANCE NV 2016 0.454% 29/01/21 REG.S - GROSS PRICE',
#  '837PY1': 'BMW FINANCE NV 2016 1 3/8% 25/10/19 REG.S - GROSS PRICE',
#  '825DT0': 'BMW FINANCE NV 2016 1% 15/02/22 REG.S - GROSS PRICE',
#  '834G1A': 'BMW FINANCE NV 2016 1% 18/08/31 REG.S - GROSS PRICE',
#  '828RH9': 'BMW FINANCE NV 2016 1/8% 15/04/20 REG.S - GROSS PRICE',
#  '834RN5': 'BMW FINANCE NV 2016 2 1/2% 24/08/20 REG.S - GROSS PRICE',
#  '828T8G': 'BMW FINANCE NV 2016 2.18% 19/04/21 REG.S - GROSS PRICE',
#  '828RJH': 'BMW FINANCE NV 2016 3/4% 15/04/24 REG.S - GROSS PRICE',
#  '824WYM': 'BMW FINANCE NV 2016 4 1/4% 04/02/26 REG.S - GROSS PRICE',
#  '840JAH': 'BMW FINANCE NV 2016 4 1/4% 23/12/19 REG.S - GROSS PRICE',
#  '834GJM': 'BMW FINANCE NV 2016 7/8% 16/08/22 REG.S - GROSS PRICE',
#  '852C35': 'BMW FINANCE NV 2017 1 1/2% 18/01/21 REG.S - GROSS PRICE',
#  '851HVM': 'BMW FINANCE NV 2017 1.73% 30/06/20 REG.S - GROSS PRICE',
#  '846JX3': 'BMW FINANCE NV 2017 1/8% 03/07/20 REG.S - GROSS PRICE',
#  '841NZW': 'BMW FINANCE NV 2017 1/8% 12/01/21 REG.S - GROSS PRICE',
#  '859R9W': 'BMW FINANCE NV 2017 2 1/2% 06/12/21 REG.S - GROSS PRICE',
#  '849D6L': 'BMW FINANCE NV 2017 2.1% 16/05/22 REG.S - GROSS PRICE',
#  '841N0E': 'BMW FINANCE NV 2017 3/4% 12/07/24 REG.S - GROSS PRICE',
#  '856ZCN': 'BMW FINANCE NV 2017 4 1/4% 18/10/20 REG.S - GROSS PRICE',
#  '846JX6': 'BMW FINANCE NV 2017 7/8% 03/04/25 REG.S - GROSS PRICE',
#  '849DAL': 'BMW FINANCE NV 2017 F/R 11/19 REG.S - GROSS PRICE',
#  '860ZUR': 'BMW FINANCE NV 2018 1 1/8% 10/01/28 REG.S - GROSS PRICE',
#  '206EE8': 'BMW FINANCE NV 2018 1 1/8% 22/05/26 REG.S - GROSS PRICE',
#  '216JJQ': 'BMW FINANCE NV 2018 1% 14/11/24 REG.S - GROSS PRICE',
#  '211Z43': 'BMW FINANCE NV 2018 1% 29/08/25 REG.S - GROSS PRICE',
#  '206EED': 'BMW FINANCE NV 2018 1/2% 22/11/22 REG.S - GROSS PRICE',
#  '216JJP': 'BMW FINANCE NV 2018 1/4% 14/01/22 REG.S - GROSS PRICE',
#  '211Z44': 'BMW FINANCE NV 2018 1/8% 29/11/21 REG.S - GROSS PRICE',
#  '860ZUQ': 'BMW FINANCE NV 2018 3/8% 10/07/23 REG.S - GROSS PRICE',
#  '2129NY': 'BMW FINANCE NV 2018 4.4% 20/09/21 REG.S - GROSS PRICE',
#  '862AVU': 'BMW FINANCE NV 2018 F/R 01/20 REG.S - GROSS PRICE',
#  '862Z5E': 'BMW FINANCE NV 2018 F/R 02/20 REG.S - GROSS PRICE',
#  '863A5J': 'BMW FINANCE NV 2018 F/R 02/20 REG.S - GROSS PRICE.1',
#  '863EH4': 'BMW FINANCE NV 2018 F/R 02/20 T EARLY - GROSS PRICE',
#  '201XML': 'BMW FINANCE NV 2018 F/R 03/20 REG.S - GROSS PRICE',
#  '203MFP': 'BMW FINANCE NV 2018 F/R 03/20 REG.S - GROSS PRICE.1',
#  '208JDC': 'BMW FINANCE NV 2018 F/R 06/20 REG.S - GROSS PRICE',
#  '207RHF': 'BMW FINANCE NV 2018 F/R 06/20 REG.S - GROSS PRICE.1',
#  '2101A2': 'BMW FINANCE NV 2018 F/R 08/20 REG.S - GROSS PRICE',
#  '213EUN': 'BMW FINANCE NV 2018 F/R 09/20 REG.S - GROSS PRICE',
#  '214T9E': 'BMW FINANCE NV 2018 F/R 10/20 REG.S - GROSS PRICE',
#  '216NP1': 'BMW FINANCE NV 2018 F/R 11/20 REG.S - GROSS PRICE',
#  '208V9K': 'BMW FINANCE NV 2018 F/R 12/19 REG.S - GROSS PRICE',
#  '240HW0': 'BMW FINANCE NV 2019 0% 24/03/23 REG.S - GROSS PRICE',
#  '220YXT': 'BMW FINANCE NV 2019 1 1/2% 06/02/29 REG.S - GROSS PRICE',
#  '232KRL': 'BMW FINANCE NV 2019 1/8% 13/07/22 REG.S - GROSS PRICE',
#  '237NXT': 'BMW FINANCE NV 2019 2 1/4% 12/08/22 REG.S - GROSS PRICE',
#  '232ZZT': 'BMW FINANCE NV 2019 2 1/4% 19/06/23 REG.S - GROSS PRICE',
#  '237NXA': 'BMW FINANCE NV 2019 2.4% 14/08/24 REG.S - GROSS PRICE',
#  '237NXK': 'BMW FINANCE NV 2019 2.85% 14/08/29 REG.S - GROSS PRICE',
#  '232KRP': 'BMW FINANCE NV 2019 3/4% 13/07/26 REG.S - GROSS PRICE',
#  '240HW1': 'BMW FINANCE NV 2019 3/8% 24/09/27 REG.S - GROSS PRICE',
#  '220YXP': 'BMW FINANCE NV 2019 5/8% 06/10/23 REG.S - GROSS PRICE',
#  '219UPN': 'BMW FINANCE NV 2019 F/R 01/21 REG.S - GROSS PRICE',
#  '227XMQ': 'BMW FINANCE NV 2019 F/R 02/21 REG.S - GROSS PRICE',
#  '232RXQ': 'BMW FINANCE NV 2019 F/R 06/23 REG.S - GROSS PRICE',
#  '237UZW': 'BMW FINANCE NV 2019 F/R 08/20 REG.S - GROSS PRICE',
#  '237QH1': 'BMW FINANCE NV 2019 F/R 08/21 REG.S - GROSS PRICE',
#  '237YRG': 'BMW FINANCE NV 2019 F/R 08/22 REG.S - GROSS PRICE',
#  '237NXH': 'BMW FINANCE NV 2019 F/R 08/22 REG.S - GROSS PRICE.1',
#  '227XLE': 'BMW FINANCE NV 2019 F/R 12/20 REG.S - GROSS PRICE',
#  '248MJ7': 'BMW FINANCE NV 2020 0% 14/04/23 REG.S - GROSS PRICE',
#  '604M0K': 'BMW FINANCE NV 2020 1 1/4% 24/08/21 REG.S - GROSS PRICE',
#  '252DZZ': 'BMW FINANCE NV 2020 2.07% 14/02/30 REG.S - GROSS PRICE',
#  '615FNP': 'BMW FINANCE NV 2020 2.8% 11/08/23 REG.S - GROSS PRICE',
#  '604EYH': 'BMW FINANCE NV 2020 3.35% 17/04/30 REG.S - GROSS PRICE',
#  '248MFD': 'BMW FINANCE NV 2020 3/8% 14/01/27 REG.S - GROSS PRICE',
#  '248MJ6': 'BMW FINANCE NV 2020 7/8% 14/01/32 REG.S - GROSS PRICE',
#  '252FWQ': 'BMW FINANCE NV 2020 F/R 02/22 REG.S - GROSS PRICE',
#  '604M4J': 'BMW FINANCE NV 2020 F/R 04/23 REG.S - GROSS PRICE',
#  '616G17': 'BMW FINANCE NV 2020 F/R 06/22 REG.S - GROSS PRICE',
#  '620AVL': 'BMW FINANCE NV 2020 F/R 10/23 REG.S - GROSS PRICE',
#  '628W3F': 'BMW FINANCE NV 2021 0% 11/01/26 REG.S - GROSS PRICE',
#  '628W5Y': 'BMW FINANCE NV 2021 0.2% 11/01/33 REG.S - GROSS PRICE',
#  '902Z1Z': 'BMW FINANCE NV 2022 1% 22/05/28 REG.S - GROSS PRICE',
#  '902Z1Y': 'BMW FINANCE NV 2022 1/2% 22/02/25 REG.S - GROSS PRICE',
#  '976MW5': 'BMW FINANCE NV 2023 3 1/2% 06/04/25 REG.S - GROSS PRICE',
#  '9768VH': 'BMW FINANCE NV 2023 3 1/2% 19/10/24 REG.S - GROSS PRICE',
#  '979HDX': 'BMW FINANCE NV 2023 3 1/4% 22/07/30 REG.S - GROSS PRICE',
#  '979HDY': 'BMW FINANCE NV 2023 3 1/4% 22/11/26 REG.S - GROSS PRICE',
#  '977J15': 'BMW FINANCE NV 2023 3 5/8% 21/10/24 REG.S - GROSS PRICE',
#  '979HDZ': 'BMW FINANCE NV 2023 3 5/8% 22/05/35 REG.S - GROSS PRICE',
#  '985CW7': 'BMW FINANCE NV 2023 F/R 07/25 REG.S - GROSS PRICE',
#  '980NJQ': 'BMW FINANCE NV 2023 F/R 12/24 REG.S - GROSS PRICE',
#  '851U2L': 'DEUTSCHE TELEKOM AG 2017 2.7% 19/07/27 REG.S - GROSS PRICE',
#  '2098Z8': 'DEUTSCHE TELEKOM AG 2018 2 1/4% 24/07/23 REG.S - GROSS PRICE',
#  '204JEJ': 'DEUTSCHE TELEKOM AG 2018 2.97% 10/04/28 REG.S - GROSS PRICE',
#  '202K7J': 'DEUTSCHE TELEKOM AG 2018 3.85% 15/03/28 REG.S - GROSS PRICE',
#  '211QE0': 'DEUTSCHE TELEKOM AG 2018 4.6% 22/08/33 REG.S - GROSS PRICE',
#  '245QRX': 'DEUTSCHE TELEKOM AG 2019 1 3/4% 09/12/49 REG.S - GROSS PRICE',
#  '223KX0': 'DEUTSCHE TELEKOM AG 2019 1 3/4% 25/03/31 REG.S - GROSS PRICE',
#  '234AXM': 'DEUTSCHE TELEKOM AG 2019 1 3/8% 05/07/34 REG.S - GROSS PRICE',
#  '234AXN': 'DEUTSCHE TELEKOM AG 2019 1/2% 05/07/27 REG.S - GROSS PRICE',
#  '224EGM': 'DEUTSCHE TELEKOM AG 2019 2 1/4% 29/03/39 REG.S - GROSS PRICE',
#  '239FD7': 'DEUTSCHE TELEKOM AG 2019 3 1/2% 06/09/39 REG.S - GROSS PRICE',
#  '220Y3P': 'DEUTSCHE TELEKOM AG 2019 3 1/8% 06/02/34 REG.S - GROSS PRICE',
#  '235H48': 'DEUTSCHE TELEKOM AG 2019 4 1/8% 23/07/49 REG.S - GROSS PRICE',
#  '223KXY': 'DEUTSCHE TELEKOM AG 2019 7/8% 25/03/26 REG.S - GROSS PRICE',
#  '250AW1': 'DEUTSCHE TELEKOM AG 2020 2 1/4% 29/03/39 T EARLY - GROSS PRICE',
#  '249CRR': 'DEUTSCHE TELEKOM AG 2020 3 5/8% 21/01/50 REG.S - GROSS PRICE',
#  '646V3X': 'DEUTSCHE TELEKOM AG 2021 1 3/4% 09/12/49 T EARLY - GROSS PRICE',
#  '640HPN': 'DEUTSCHE TELEKOM AG 2021 3 1/2% 15/04/41 REG.S - GROSS PRICE',
#  '216511': 'DT.TKOM.INTL.FIN. 2000 G/R 15/06/30 S - GROSS PRICE',
#  '216514': 'DT.TKOM.INTL.FIN. 2000 G/R 15/06/30 S - GROSS PRICE.1',
#  '23124L': 'DT.TKOM.INTL.FIN. 2002 7 3/8% 04/12/19 REG.S - GROSS PRICE',
#  '21378U': 'DT.TKOM.INTL.FIN. 2002 9 1/4% 01/06/32 3 - GROSS PRICE',
#  '23548P': 'DT.TKOM.INTL.FIN. 2003 7 1/2% 24/01/33 - GROSS PRICE',
#  '2055QV': 'DT.TKOM.INTL.FIN. 2008 5.851% 17/03/23 REG.S - GROSS PRICE',
#  '2528E9': 'DT.TKOM.INTL.FIN. 2008 8 7/8% 27/11/28 REG.S - GROSS PRICE',
#  '3891N1': 'DT.TKOM.INTL.FIN. 2009 5 3/8% 27/07/21 REG.S - GROSS PRICE',
#  '3778QU': 'DT.TKOM.INTL.FIN. 2009 6 1/2% 08/04/22 REG.S - GROSS PRICE',
#  '6109XT': 'DT.TKOM.INTL.FIN. 2010 4 1/2% 28/10/30 REG.S - GROSS PRICE',
#  '5688JF': 'DT.TKOM.INTL.FIN. 2010 4 1/4% 13/07/22 REG.S - GROSS PRICE',
#  '5586U5': 'DT.TKOM.INTL.FIN. 2010 4 1/4% 16/03/20 REG.S - GROSS PRICE',
#  '5613V5': 'DT.TKOM.INTL.FIN. 2010 4 7/8% 22/04/25 REG.S - GROSS PRICE',
#  '6037K3': 'DT.TKOM.INTL.FIN. 2010 4.628% 25/01/22 - GROSS PRICE',
#  '8050Z1': 'DT.TKOM.INTL.FIN. 2012 2 3/4% 24/10/24 REG.S - GROSS PRICE',
#  '8070QG': 'DT.TKOM.INTL.FIN. 2012 2% 30/10/19 REG.S - GROSS PRICE',
#  '8209NY': 'DT.TKOM.INTL.FIN. 2012 3% 21/12/32 REG.S - GROSS PRICE',
#  '7812L4': 'DT.TKOM.INTL.FIN. 2012 4 7/8% 06/03/42 REG.S - GROSS PRICE',
#  '7471N6': 'DT.TKOM.INTL.FIN. 2012 4.3% 20/01/27 - GROSS PRICE',
#  '8283Z7': 'DT.TKOM.INTL.FIN. 2013 2 1/8% 18/01/21 REG.S - GROSS PRICE',
#  '783FPV': 'DT.TKOM.INTL.FIN. 2013 3 1/2% 15/07/33 - GROSS PRICE',
#  '8283Z8': 'DT.TKOM.INTL.FIN. 2013 3 1/4% 17/01/28 REG.S - GROSS PRICE',
#  '8375YT': 'DT.TKOM.INTL.FIN. 2013 3.55% 11/02/33 - GROSS PRICE',
#  '8303ZF': 'DT.TKOM.INTL.FIN. 2013 3.55% 17/01/33 - GROSS PRICE',
#  '8623ZZ': 'DT.TKOM.INTL.FIN. 2013 3.9% 22/04/33 REG.S - GROSS PRICE',
#  '827NC3': 'DT.TKOM.INTL.FIN. 2016 1 1/2% 03/04/28 REG.S - GROSS PRICE',
#  '836RZU': 'DT.TKOM.INTL.FIN. 2016 1 1/4% 06/10/23 REG.S - GROSS PRICE',
#  '835VGT': 'DT.TKOM.INTL.FIN. 2016 1.95% 19/09/21 REG.S - GROSS PRICE',
#  '828T1J': 'DT.TKOM.INTL.FIN. 2016 1/4% 19/04/21 REG.S - GROSS PRICE',
#  '835VGU': 'DT.TKOM.INTL.FIN. 2016 2.485% 19/09/23 EARLY - GROSS PRICE',
#  '827NC2': 'DT.TKOM.INTL.FIN. 2016 5/8% 03/04/23 REG.S - GROSS PRICE',
#  '841FGT': 'DT.TKOM.INTL.FIN. 2016 F/R 04/20 Q - GROSS PRICE',
#  '827NC9': 'DT.TKOM.INTL.FIN. 2016 F/R 04/20 REG.S - GROSS PRICE',
#  '849A0F': 'DT.TKOM.INTL.FIN. 2017 1 1/8% 22/05/26 REG.S - GROSS PRICE',
#  '842RE0': 'DT.TKOM.INTL.FIN. 2017 1 3/8% 30/01/27 REG.S - GROSS PRICE',
#  '846V6R': 'DT.TKOM.INTL.FIN. 2017 2 1/4% 13/04/29 REG.S - GROSS PRICE',
#  '841UG2': 'DT.TKOM.INTL.FIN. 2017 2.225% 17/01/20 REG.S - GROSS PRICE',
#  '841UGX': 'DT.TKOM.INTL.FIN. 2017 2.82% 19/01/22 EARLY - GROSS PRICE',
#  '847HFX': 'DT.TKOM.INTL.FIN. 2017 2.95% 19/04/27 REG.S - GROSS PRICE',
#  '841UG3': 'DT.TKOM.INTL.FIN. 2017 3.6% 19/01/27 REG.S - GROSS PRICE',
#  '842REU': 'DT.TKOM.INTL.FIN. 2017 3/8% 30/10/21 REG.S - GROSS PRICE',
#  '859V73': 'DT.TKOM.INTL.FIN. 2017 5/8% 13/12/24 REG.S - GROSS PRICE',
#  '842RE3': 'DT.TKOM.INTL.FIN. 2017 7/8% 30/01/24 REG.S - GROSS PRICE',
#  '841UHG': 'DT.TKOM.INTL.FIN. 2017 F/R 01/20 REG.S - GROSS PRICE',
#  '206UEX': 'DT.TKOM.INTL.FIN. 2018 1 3/8% 01/12/25 REG.S - GROSS PRICE',
#  '214GAN': 'DT.TKOM.INTL.FIN. 2018 2 1/2% 10/10/25 REG.S - GROSS PRICE',
#  '206UEQ': 'DT.TKOM.INTL.FIN. 2018 2% 01/12/29 REG.S - GROSS PRICE',
#  '2099ZL': 'DT.TKOM.INTL.FIN. 2018 2.2% 25/07/33 REG.S - GROSS PRICE',
#  '208FEV': 'DT.TKOM.INTL.FIN. 2018 4 3/4% 21/06/38 REG.S - GROSS PRICE',
#  '208FEU': 'DT.TKOM.INTL.FIN. 2018 4 3/8% 21/06/28 REG.S - GROSS PRICE',
#  '207H2Z': 'DT.TKOM.INTL.FIN. 2018 5/8% 01/12/22 REG.S - GROSS PRICE',
#  '862FK7': 'DT.TKOM.INTL.FIN. 2018 F/R 01/20 REG.S - GROSS PRICE',
#  '206UEV': 'DT.TKOM.INTL.FIN. 2018 F/R 12/22 REG.S - GROSS PRICE',
#  '848Y6V': 'E ON SE 2017 1 5/8% 22/05/29 REG.S - GROSS PRICE',
#  '848Y6X': 'E ON SE 2017 3/8% 23/08/21 EARLY - GROSS PRICE',
#  '848Y6W': 'E ON SE 2017 7/8% 22/05/24 REG.S - GROSS PRICE',
#  '242MKW': 'E ON SE 2019 0% 24/10/22 REG.S - GROSS PRICE',
#  '238PXP': 'E ON SE 2019 0% 28/08/24 REG.S - GROSS PRICE',
#  '246ADU': 'E ON SE 2019 0% 29/09/22 REG.S - GROSS PRICE',
#  '238PXC': 'E ON SE 2019 0.35% 28/02/30 REG.S - GROSS PRICE',
#  '242MLD': 'E ON SE 2019 1/4% 24/10/26 REG.S - GROSS PRICE',
#  '620EV6': 'E ON SE 2019 3 1/2% 26/10/37 - GROSS PRICE',
#  '243PCA': 'E ON SE 2019 5/8% 07/11/31 REG.S - GROSS PRICE',
#  '248P9T': 'E ON SE 2020 0% 18/12/23 REG.S - GROSS PRICE',
#  '603EET': 'E ON SE 2020 1% 07/10/25 REG.S - GROSS PRICE',
#  '248QAJ': 'E ON SE 2020 3/4% 18/12/30 REG.S - GROSS PRICE',
#  '607CA5': 'E ON SE 2020 3/4% 20/02/28 REG.S - GROSS PRICE',
#  '607CA6': 'E ON SE 2020 3/8% 20/04/23 REG.S - GROSS PRICE',
#  '248P9U': 'E ON SE 2020 3/8% 29/09/27 REG.S - GROSS PRICE',
#  '607CA7': 'E ON SE 2020 7/8% 20/08/31 REG.S - GROSS PRICE',
#  '6295ZJ': 'E ON SE 2021 0.1% 19/12/28 REG.S - GROSS PRICE',
#  '638M44': 'E ON SE 2021 0.6% 01/10/32 REG.S - GROSS PRICE',
#  '910F4T': 'E ON SE 2022 1 5/8% 29/03/31 REG.S - GROSS PRICE',
#  '666P36': 'E ON SE 2022 1/8% 18/01/26 REG.S - GROSS PRICE',
#  '949GXF': 'E ON SE 2022 2 7/8% 26/08/28 REG.S - GROSS PRICE',
#  '910F4H': 'E ON SE 2022 7/8% 08/01/25 REG.S - GROSS PRICE',
#  '666P37': 'E ON SE 2022 7/8% 18/10/34 REG.S - GROSS PRICE',
#  '9659AJ': 'E ON SE 2023 3 1/2% 12/01/28 REG.S - GROSS PRICE',
#  '9659AL': 'E ON SE 2023 3 7/8% 12/01/35 REG.S - GROSS PRICE',
#  '791G5Y': 'ENBW ENGE.BA.WUERT. 2014 3.625%(F/R)04/76 EARLY - GROSS PRICE',
#  '836P83': 'ENBW ENGE.BA.WUERT. 2016 3.375%(F/R)04/77 EARLY - GROSS PRICE',
#  '836K64': 'ENBW ENGE.BA.WUERT. 2016 5.125%(F/R)04/77 EARLY - GROSS PRICE',
#  '236GF6': 'ENBW ENGE.BA.WUERT. 2019 1.125%(F/R)11/79 REG.S - GROSS PRICE',
#  '236GF9': 'ENBW ENGE.BA.WUERT. 2019 1.625%(F/R)08/79 REG.S - GROSS PRICE',
#  '610W5G': 'ENBW ENGE.BA.WUERT. 2020 1.875%(F/R)06/80 REG.S - GROSS PRICE',
#  '653J02': 'ENBW ENGE.BA.WUERT. 2021 1.375%(F/R)08/81 REG.S - GROSS PRICE',
#  '655NCP': 'ENBW ENGE.BA.WUERT. 2021 2.125%(F/R)08/81 REG.S - GROSS PRICE',
#  '478517': 'ENBW INTL.FINANCE 2004 4 7/8% 16/01/25 REG.S - GROSS PRICE',
#  '5989VD': 'ENBW INTL.FINANCE 2008 3.88% 16/12/38 REG.S - GROSS PRICE',
#  '3878R6': 'ENBW INTL.FINANCE 2009 6 1/8% 07/07/39 REG.S - GROSS PRICE',
#  '794GNW': 'ENBW INTL.FINANCE 2014 2 1/2% 04/06/26 REG.S - GROSS PRICE',
#  '794XUZ': 'ENBW INTL.FINANCE 2014 2 7/8% 13/06/34 19 - GROSS PRICE',
#  '794Q4D': 'ENBW INTL.FINANCE 2014 3.08% 16/06/39 18 - GROSS PRICE',
#  '215K7D': 'ENBW INTL.FINANCE 2018 1 7/8% 31/10/33 REG.S - GROSS PRICE',
#  '219Y2E': 'ENBW INTL.FINANCE 2019 2.08% 21/01/40 REG.S - GROSS PRICE',
#  '621JA3': 'ENBW INTL.FINANCE 2020 1/4% 19/10/30 REG.S - GROSS PRICE',
#  '603TFE': 'ENBW INTL.FINANCE 2020 5/8% 17/04/25 REG.S - GROSS PRICE',
#  '634U03': 'ENBW INTL.FINANCE 2021 1/2% 01/03/33 REG.S - GROSS PRICE',
#  '634U01': 'ENBW INTL.FINANCE 2021 1/8% 01/03/28 REG.S - GROSS PRICE',
#  '669JY7': 'ENBW INTL.FINANCE 2022 0% 14/02/34 EARLY - GROSS PRICE',
#  '669JYX': 'ENBW INTL.FINANCE 2022 0% 14/03/29 EARLY - GROSS PRICE',
#  '9587MM': 'ENBW INTL.FINANCE 2022 3 5/8% 22/11/26 REG.S - GROSS PRICE',
#  '9587L1': 'ENBW INTL.FINANCE 2022 4.049% 22/11/29 REG.S - GROSS PRICE',
#  '968XD1': 'ENBW INTL.FINANCE 2023 3 1/2% 24/07/28 REG.S - GROSS PRICE',
#  '9679CN': 'ENBW INTL.FINANCE 2023 4% 24/01/35 REG.S - GROSS PRICE',
#  '83067Y': 'INNOGY FINANCE BV 2013 1 7/8% 30/01/20 REG.S - GROSS PRICE',
#  '220MC9': 'INNOGY FINANCE BV 2019 3/4% 31/07/23 EARLY - GROSS PRICE',
#  '8116HA': 'LANXESS AG 2012 2 5/8% 21/11/22 REG.S - GROSS PRICE',
#  '7857KN': 'LANXESS AG 2012 3 1/2% 05/04/22 6 - GROSS PRICE',
#  '7857NF': 'LANXESS AG 2012 3.95% 05/04/27 REG.S - GROSS PRICE',
#  '836R40': 'LANXESS AG 2016 1% 07/10/26 REG.S - GROSS PRICE',
#  '836R4Z': 'LANXESS AG 2016 1/4% 07/10/21 EARLY - GROSS PRICE',
#  '839RNV': 'LANXESS AG 2016 4.5%(F/R) 12/76 EARLY - GROSS PRICE',
#  '205ZFY': 'LANXESS AG 2018 1 1/8% 16/05/25 REG.S - GROSS PRICE',
#  '654F5Q': 'LANXESS AG 2021 0% 08/09/27 REG.S - GROSS PRICE',
#  '662P28': 'LANXESS AG 2021 5/8% 01/12/29 REG.S - GROSS PRICE',
#  '909H1D': 'LANXESS AG 2022 1 3/4% 22/03/28 REG.S - GROSS PRICE',
#  '8182FH': 'METRO AG 2012 4% 09/08/27 REG.S - GROSS PRICE',
#  '8005PX': 'METRO AG 2012 4% 10/07/24 25 - GROSS PRICE',
#  '8004MJ': 'METRO AG 2012 4% 11/07/22 26 - GROSS PRICE',
#  '7449TF': 'METRO AG 2012 4.05% 20/01/20 19 - GROSS PRICE',
#  '799VNC': 'METRO AG 2014 1 3/8% 28/10/21 REG.S - GROSS PRICE',
#  '807TAD': 'METRO AG 2015 1 1/2% 19/03/25 REG.S - GROSS PRICE',
#  '201U9K': 'METRO AG 2018 1 1/8% 06/03/23 REG.S - GROSS PRICE',
#  '976C8H': 'SIEMENS ENERGY FIN 2023 4 1/4% 05/04/29 REG.S - GROSS PRICE',
#  '976EKM': 'SIEMENS ENERGY FIN 2023 4% 05/04/26 REG.S - GROSS PRICE',
#  '950VFT': 'SIEMENS ENERGY FIN CV 5 5/8% 14/09/25 REG.S - GROSS PRICE',
#  '78882V': 'SIEMENS FINMCH 2006 6 1/8% 17/08/26 REG.S - GROSS PRICE',
#  '8386LT': 'SIEMENS FINMCH 2012 1 1/2% 10/03/20 - GROSS PRICE',
#  '8386LP': 'SIEMENS FINMCH 2012 2 3/4% 10/09/25 REG.S - GROSS PRICE',
#  '8386LU': 'SIEMENS FINMCH 2012 3 3/4% 10/09/42 REG.S - GROSS PRICE',
#  '84528Y': 'SIEMENS FINMCH 2013 1 3/4% 12/03/21 REG.S - GROSS PRICE',
#  '84529A': 'SIEMENS FINMCH 2013 2 7/8% 10/03/28 REG.S - GROSS PRICE',
#  '8490JA': 'SIEMENS FINMCH 2013 3 1/2% 20/03/28 S - GROSS PRICE',
#  '811TW0': 'SIEMENS FINMCH 2015 2.15% 27/05/20 REG.S - GROSS PRICE',
#  '811TW9': 'SIEMENS FINMCH 2015 2.9% 27/05/22 REG.S - GROSS PRICE',
#  '811TXC': 'SIEMENS FINMCH 2015 3 1/4% 27/05/25 REG.S - GROSS PRICE',
#  '811TXE': 'SIEMENS FINMCH 2015 4.4% 27/05/45 REG.S - GROSS PRICE',
#  '835K47': 'SIEMENS FINMCH 2016 1.7% 15/09/21 REG.S - GROSS PRICE',
#  '835K45': 'SIEMENS FINMCH 2016 2% 15/09/23 REG.S - GROSS PRICE',
#  '835K48': 'SIEMENS FINMCH 2016 2.35% 15/10/26 REG.S - GROSS PRICE',
#  '835K46': 'SIEMENS FINMCH 2016 3.3% 15/09/46 REG.S - GROSS PRICE',
#  '845G2Y': 'SIEMENS FINMCH 2017 2.2% 16/03/20 REG.S - GROSS PRICE',
#  '845G2L': 'SIEMENS FINMCH 2017 2.7% 16/03/22 REG.S - GROSS PRICE',
#  '845G2T': 'SIEMENS FINMCH 2017 3 1/8% 16/03/24 REG.S - GROSS PRICE',
#  '845G28': 'SIEMENS FINMCH 2017 3.4% 16/03/27 REG.S - GROSS PRICE',
#  '845G3E': 'SIEMENS FINMCH 2017 4.2% 16/03/47 REG.S - GROSS PRICE',
#  '845G3M': 'SIEMENS FINMCH 2017 F/R 03/20 REG.S - GROSS PRICE',
#  '845G2M': 'SIEMENS FINMCH 2017 F/R 03/22 REG.S - GROSS PRICE',
#  '212CZN': 'SIEMENS FINMCH 2018 1 3/8% 06/09/30 REG.S - GROSS PRICE',
#  '212CYN': 'SIEMENS FINMCH 2018 1% 06/09/27 REG.S - GROSS PRICE',
#  '212CYM': 'SIEMENS FINMCH 2018 3/8% 06/09/23 REG.S - GROSS PRICE',
#  '238YZD': 'SIEMENS FINMCH 2019 0% 05/09/21 REG.S - GROSS PRICE',
#  '238Y1P': 'SIEMENS FINMCH 2019 0% 05/09/24 REG.S - GROSS PRICE',
#  '221Z4F': 'SIEMENS FINMCH 2019 0.3% 28/02/24 REG.S - GROSS PRICE',
#  '221Z4L': 'SIEMENS FINMCH 2019 0.9% 28/02/28 REG.S - GROSS PRICE',
#  '221Z4N': 'SIEMENS FINMCH 2019 1 1/4% 28/02/31 REG.S - GROSS PRICE',
#  '221Z8Z': 'SIEMENS FINMCH 2019 1 3/4% 28/02/39 REG.S - GROSS PRICE',
#  '238Y1E': 'SIEMENS FINMCH 2019 1/2% 05/09/34 REG.S - GROSS PRICE',
#  '238Y1F': 'SIEMENS FINMCH 2019 1/8% 05/09/29 REG.S - GROSS PRICE',
#  '246PCT': 'SIEMENS FINMCH 2019 F/R 12/21 REG.S - GROSS PRICE',
#  '2514FZ': 'SIEMENS FINMCH 2020 0% 20/02/23 REG.S - GROSS PRICE',
#  '2515AQ': 'SIEMENS FINMCH 2020 0% 20/02/26 REG.S - GROSS PRICE',
#  '25141Y': 'SIEMENS FINMCH 2020 1% 20/02/25 REG.S - GROSS PRICE',
#  '2515AX': 'SIEMENS FINMCH 2020 1/2% 20/02/32 REG.S - GROSS PRICE',
#  '608H20': 'SIEMENS FINMCH 2020 1/4% 05/06/24 REG.S - GROSS PRICE',
#  '2515AR': 'SIEMENS FINMCH 2020 1/4% 20/02/29 REG.S - GROSS PRICE',
#  '608H2V': 'SIEMENS FINMCH 2020 1/8% 05/06/22 REG.S - GROSS PRICE',
#  '608H2Z': 'SIEMENS FINMCH 2020 3/8% 05/06/26 REG.S - GROSS PRICE',
#  '608H24': 'SIEMENS FINMCH 2020 7/8% 05/06/23 REG.S - GROSS PRICE',
#  '635ZMQ': 'SIEMENS FINMCH 2021 0.4% 11/03/23 REG.S - GROSS PRICE',
#  '635ZM2': 'SIEMENS FINMCH 2021 0.65% 11/03/24 REG.S - GROSS PRICE',
#  '635ZNV': 'SIEMENS FINMCH 2021 1.2% 11/03/26 REG.S - GROSS PRICE',
#  '635ZM1': 'SIEMENS FINMCH 2021 1.7% 11/03/28 REG.S - GROSS PRICE',
#  '635ZN1': 'SIEMENS FINMCH 2021 2 7/8% 11/03/41 REG.S - GROSS PRICE',
#  '635ZNJ': 'SIEMENS FINMCH 2021 2.15% 11/03/31 REG.S - GROSS PRICE',
#  '635ZN3': 'SIEMENS FINMCH 2021 F/R 03/24 REG.S - GROSS PRICE',
#  '9026ZY': 'SIEMENS FINMCH 2022 1 1/4% 25/02/35 REG.S - GROSS PRICE',
#  '90260A': 'SIEMENS FINMCH 2022 1% 25/02/30 REG.S - GROSS PRICE',
#  '9498UX': 'SIEMENS FINMCH 2022 2 1/2% 08/09/27 REG.S - GROSS PRICE',
#  '9498M4': 'SIEMENS FINMCH 2022 2 1/4% 10/03/25 REG.S - GROSS PRICE',
#  '9498M5': 'SIEMENS FINMCH 2022 2 3/4% 09/09/30 REG.S - GROSS PRICE',
#  '9498WP': 'SIEMENS FINMCH 2022 3% 08/09/33 REG.S - GROSS PRICE',
#  '9026ZP': 'SIEMENS FINMCH 2022 5/8% 25/02/27 REG.S - GROSS PRICE',
#  '970E9V': 'SIEMENS FINMCH 2023 3 1/2% 24/02/36 REG.S - GROSS PRICE',
#  '970E9R': 'SIEMENS FINMCH 2023 3 3/8% 24/08/31 REG.S - GROSS PRICE',
#  '970E9T': 'SIEMENS FINMCH 2023 3 5/8% 24/02/43 REG.S - GROSS PRICE',
#  '55848N': 'SUEDZUCKER INFN BV 2005 5.25%(F/R) PERP. REG.S - GROSS PRICE',
#  '839KZR': 'SUEDZUCKER INFN BV 2016 1 1/4% 29/11/23 REG.S - GROSS PRICE',
#  '859JTX': 'SUEDZUCKER INFN BV 2017 1% 28/11/25 REG.S - GROSS PRICE',
#  '957KRL': 'SUEDZUCKER INFN BV 2022 5 1/8% 31/10/27 REG.S - GROSS PRICE',
#  '809FQA': 'VOLKSWAGEN FNSR. 2015 3/4% 14/10/21 REG.S - GROSS PRICE',
#  '214P2W': 'VOLKSWAGEN FNSR. 2018 1 3/8% 16/10/23 REG.S - GROSS PRICE',
#  '214P1N': 'VOLKSWAGEN FNSR. 2018 1/4% 16/10/20 REG.S - GROSS PRICE',
#  '214P02': 'VOLKSWAGEN FNSR. 2018 2 1/4% 16/10/26 REG.S - GROSS PRICE',
#  '204ATV': 'VOLKSWAGEN FNSR. 2018 3/8% 12/04/21 REG.S - GROSS PRICE',
#  '204AUM': 'VOLKSWAGEN FNSR. 2018 7/8% 12/04/23 REG.S - GROSS PRICE',
#  '209RXK': 'VOLKSWAGEN FNSR. 2018 F/R 07/20 REG.S - GROSS PRICE',
#  '209U5E': 'VOLKSWAGEN FNSR. 2018 F/R 07/20 REG.S - GROSS PRICE.1',
#  '204ATU': 'VOLKSWAGEN FNSR. 2018 F/R 10/19 REG.S - GROSS PRICE',
#  '224GPN': 'VOLKSWAGEN FNSR. 2019 1 1/2% 01/10/24 REG.S - GROSS PRICE',
#  '224HUJ': 'VOLKSWAGEN FNSR. 2019 2 1/4% 01/10/27 REG.S - GROSS PRICE',
#  '224GNZ': 'VOLKSWAGEN FNSR. 2019 5/8% 01/04/22 REG.S - GROSS PRICE',
#  '221MN5': 'VOLKSWAGEN FNSR. 2019 F/R 02/21 REG.S - GROSS PRICE',
#  '618KRN': 'VOLKSWAGEN FNSR. 2020 0.16% 16/09/21 REG.S - GROSS PRICE',
#  '603EEJ': 'VOLKSWAGEN FNSR. 2020 2 1/2% 06/04/23 REG.S - GROSS PRICE',
#  '603AXD': 'VOLKSWAGEN FNSR. 2020 3 3/8% 06/04/28 REG.S - GROSS PRICE',
#  '603AXG': 'VOLKSWAGEN FNSR. 2020 3% 06/04/25 REG.S - GROSS PRICE',
#  '618K6R': 'VOLKSWAGEN FNSR. 2020 F/R 09/21 REG.S - GROSS PRICE',
#  '651PGT': 'VOLKSWAGEN FNSR. 2021 0% 12/02/25 REG.S - GROSS PRICE',
#  '651PGR': 'VOLKSWAGEN FNSR. 2021 1/8% 12/02/27 REG.S - GROSS PRICE',
#  '651PGV': 'VOLKSWAGEN FNSR. 2021 3/8% 12/02/30 REG.S - GROSS PRICE',
#  '6386YQ': 'VOLKSWAGEN FNSR. 2021 F/R 04/23 REG.S - GROSS PRICE',
#  '668CN4': 'VOLKSWAGEN FNSR. 2022 1/4% 31/01/25 REG.S - GROSS PRICE',
#  '668CN5': 'VOLKSWAGEN FNSR. 2022 7/8% 31/01/28 REG.S - GROSS PRICE',
#  '965X4G': 'VOLKSWAGEN FNSR. 2023 F/R 04/24 REG.S - GROSS PRICE',
#  '5716Q7': 'VW INTL FIN NV 2010 4% 12/08/20 REG.S - GROSS PRICE',
#  '82647Z': 'VW INTL FIN NV 2013 2% 14/01/20 REG.S - GROSS PRICE',
#  '8526YM': 'VW INTL FIN NV 2013 2% 26/03/21 REG.S - GROSS PRICE',
#  '8538NG': 'VW INTL FIN NV 2013 3 1/2% 02/04/43 REG.S - GROSS PRICE',
#  '8512ZV': 'VW INTL FIN NV 2013 3.3% 22/03/33 REG.S - GROSS PRICE',
#  '784TED': 'VW INTL FIN NV 2013 5.125%(F/R)PERP. REG.S - GROSS PRICE',
#  '795H63': 'VW INTL FIN NV 2014 3% 01/07/39 REG.S - GROSS PRICE',
#  '792F3Q': 'VW INTL FIN NV 2014 3% 11/04/29 REG.S - GROSS PRICE',
#  '789PLC': 'VW INTL FIN NV 2014 3.4% 30/01/34 REG.S - GROSS PRICE',
#  '791NQU': 'VW INTL FIN NV 2014 3.75%(F/R) PERP. EARLY - GROSS PRICE',
#  '791NZH': 'VW INTL FIN NV 2014 4.625%(F/R)PERP. REG.S - GROSS PRICE',
#  '803NN9': 'VW INTL FIN NV 2015 1 5/8% 16/01/30 REG.S - GROSS PRICE',
#  '804XTV': 'VW INTL FIN NV 2015 1/2% 20/02/20 - GROSS PRICE',
#  '808D9J': 'VW INTL FIN NV 2015 2.5%(F/R) PERP. EARLY - GROSS PRICE',
#  '808D9K': 'VW INTL FIN NV 2015 3.5%(F/R) PERP. REG.S - GROSS PRICE',
#  '803NPD': 'VW INTL FIN NV 2015 7/8% 16/01/23 REG.S - GROSS PRICE',
#  '846ERM': 'VW INTL FIN NV 2017 1 1/8% 02/10/23 REG.S - GROSS PRICE',
#  '846ERT': 'VW INTL FIN NV 2017 1 7/8% 30/03/27 REG.S - GROSS PRICE',
#  '846EQR': 'VW INTL FIN NV 2017 1/2% 30/03/21 REG.S - GROSS PRICE',
#  '850JUH': 'VW INTL FIN NV 2017 2.7%(F/R) PERP. EARLY - GROSS PRICE',
#  '850JU7': 'VW INTL FIN NV 2017 3.875%(F/R)PERP. REG.S - GROSS PRICE',
#  '216NPP': 'VW INTL FIN NV 2018 2 5/8% 16/11/27 REG.S - GROSS PRICE',
#  '216NPQ': 'VW INTL FIN NV 2018 3 1/4% 18/11/30 REG.S - GROSS PRICE',
#  '216NPT': 'VW INTL FIN NV 2018 3 3/8% 16/11/26 REG.S - GROSS PRICE',
#  '208PQL': 'VW INTL FIN NV 2018 3.375%(F/R)PERP. REG.S - GROSS PRICE',
#  '216NPR': 'VW INTL FIN NV 2018 4 1/8% 16/11/38 REG.S - GROSS PRICE',
#  '216NPU': 'VW INTL FIN NV 2018 4 1/8% 17/11/31 REG.S - GROSS PRICE',
#  '208PTJ': 'VW INTL FIN NV 2018 4 5/8% PERP. REG.S - GROSS PRICE',
#  '216NPN': 'VW INTL FIN NV 2018 F/R 11/24 REG.S - GROSS PRICE',
#  '626GC0': 'VW INTL FIN NV 2020 0.05% 10/06/24 REG.S - GROSS PRICE',
#  '619AKZ': 'VW INTL FIN NV 2020 1 1/4% 23/09/32 REG.S - GROSS PRICE',
#  '626NZW': 'VW INTL FIN NV 2020 3.4% 08/12/23 REG.S - GROSS PRICE',
#  '609MUP': 'VW INTL FIN NV 2020 3.5%(F/R) PERP. REG.S - GROSS PRICE',
#  '609MUR': 'VW INTL FIN NV 2020 3.875%(F/R)PERP. REG.S - GROSS PRICE',
#  '619AKG': 'VW INTL FIN NV 2020 7/8% 22/09/28 REG.S - GROSS PRICE',
#  '630MLZ': 'VW INTL FIN NV 2021 1 1/2% 21/01/41 REG.S - GROSS PRICE',
#  '630K03': 'VW INTL FIN NV 2021 2.9% 21/01/24 REG.S - GROSS PRICE',
#  '630GZ8': 'VW INTL FIN NV 2021 F/R 07/22 REG.S - GROSS PRICE',
#  '930JDP': 'VW INTL FIN NV 2022 3 1/8% 28/03/25 REG.S - GROSS PRICE',
#  '930JDW': 'VW INTL FIN NV 2022 3 3/4% 28/09/27 REG.S - GROSS PRICE',
#  '9097VQ': 'VW INTL FIN NV 2022 3.748%(F/R)PERP. REG.S - GROSS PRICE',
#  '958FP9': 'VW INTL FIN NV 2022 4 1/4% 15/02/28 REG.S - GROSS PRICE',
#  '958FQD': 'VW INTL FIN NV 2022 4 1/8% 15/11/25 REG.S - GROSS PRICE',
#  '958FP7': 'VW INTL FIN NV 2022 4 3/8% 15/05/30 REG.S - GROSS PRICE',
#  '9097VR': 'VW INTL FIN NV 2022 4.375%(F/R)PERP. REG.S - GROSS PRICE',
#  '973URD': 'VW INTL FIN NV 2023 3 7/8% 29/03/26 REG.S - GROSS PRICE',
#  '973UU7': 'VW INTL FIN NV 2023 4 1/4% 29/03/29 REG.S - GROSS PRICE',
#  '979MZH': 'VW INTL FIN NV 2023 4.58% 30/05/26 - GROSS PRICE',
#  '9790M1': 'VW INTL FIN NV 2023 4.86% 02/06/25 - GROSS PRICE',
#  '17015D(GP)': 'INNOGY FINANCE BV 2001 6 1/4% 20/04/16 11012',
#  '21084E(GP)': 'INNOGY FINANCE BV 2002 6 1/8% 26/10/12 11022',
#  '25258N(GP)': 'INNOGY FINANCE BV 2003 5 1/8% 23/07/18 REG.S',
#  '46282M(GP)': 'INNOGY FINANCE BV 2004 4 5/8% 23/07/14',
#  '2520U6(GP)': 'INNOGY FINANCE BV 2008 6 5/8% 31/01/19 REG.S',
#  '3855EN(GP)': 'INNOGY FINANCE BV 2009 2 1/2% 16/09/11 11093',
#  '3697RQ(GP)': 'INNOGY FINANCE BV 2009 5% 10/02/15 11091',
#  '83067Y(GP)': 'INNOGY FINANCE BV 2013 1 7/8% 30/01/20 REG.S',
#  '220MC9(GP)': 'INNOGY FINANCE BV 2019 3/4% 31/07/23 EARLY'}

# %%
new_row = [dictionary2[col] for col in df1.columns]

# Insert the new row at the first position in df1
df1.loc[-1] = new_row  # Add new row at the end
df1.index = df1.index + 1  # Shift the index
df1 = df1.sort_index()  # Sort the index so that the new row is at the top

df2.loc[-1] = new_row  # Add new row at the end
df2.index = df2.index + 1  # Shift the index
df2 = df2.sort_index()

df3.loc[-1] = new_row  # Add new row at the end
df3.index = df3.index + 1  # Shift the index
df3 = df3.sort_index()

df4.loc[-1] = new_row  # Add new row at the end
df4.index = df4.index + 1  # Shift the index
df4 = df4.sort_index()

# %%
df1_transposed = df1.transpose()
df1_transposed_sorted = df1_transposed.sort_values(by=0)
df1 = df1_transposed_sorted.transpose()

df2_transposed = df2.transpose()
df2_transposed_sorted = df2_transposed.sort_values(by=0)
df2 = df2_transposed_sorted.transpose()

df3_transposed = df3.transpose()
df3_transposed_sorted = df3_transposed.sort_values(by=0)
df3 = df3_transposed_sorted.transpose()

df4_transposed = df4.transpose()
df4_transposed_sorted = df4_transposed.sort_values(by=0)
df4 = df4_transposed_sorted.transpose()

# %%
df_columns = set(df1.columns)
dict_keys = set(dictionary2.keys())

# Find columns in DataFrame that are not in the dictionary
missing_in_dict = df_columns - dict_keys

# Find keys in the dictionary that are not in the DataFrame columns
extra_in_dict = dict_keys - df_columns

print("Columns in DataFrame not in dictionary:", missing_in_dict)
print("Keys in dictionary not in DataFrame columns:", extra_in_dict)
# Out:
# Columns in DataFrame not in dictionary: set()
# Keys in dictionary not in DataFrame columns: {'655NCP', '249CRR', '238PXC', '220MC9(GP)', '236GF6', '248P9T', '8386LU', '791G5Y', '603EET', '17015D(GP)', '242MLD', '8538NG', '3855EN(GP)', 'Code', '638M44', '836K64', '836P83', '839RNV', '9659AJ', '848Y6W', '845G3E', '242MKW', '7812L4', '646V3X', 'nan', '610W5G', '607CA5', '8116HA', '238PXP', '220MC9', '848Y6V', '6295ZJ', '607CA6', '607CA7', '620EV6', '848Y6X', '910F4H', '949GXF', '248P9U', '653J02', '630MLZ', '236GF9', '811TXE', '248QAJ', '666P36', '83067Y(GP)', '9659AL', '246ADU', '245QRX', '835K46', '243PCA', '666P37', '2520U6(GP)', '46282M(GP)', '25258N(GP)', '21084E(GP)', '910F4T', '3697RQ(GP)', '83067Y'}

# %%
df1.loc[0] = [str(value).split()[0] for value in df1.loc[0]]
df2.loc[0] = [str(value).split()[0] for value in df2.loc[0]]
df3.loc[0] = [str(value).split()[0] for value in df3.loc[0]]
df4.loc[0] = [str(value).split()[0] for value in df4.loc[0]]

# %%
row_0_values = df2.loc[0].dropna().unique()  # Drop NaNs and get unique values


all_values = df2.values.flatten()
value_counts = pd.Series(all_values).value_counts()

counts = {value: value_counts.get(value, 0) for value in row_0_values}

print(counts)
# Out:
# {'BASF': 33, 'BMW': 95, 'DEUTSCHE': 15, 'DT.TKOM.INTL.FIN.': 52, 'ENBW': 18, 'LANXESS': 8, 'METRO': 7, 'SIEMENS': 59, 'SUEDZUCKER': 4, 'VOLKSWAGEN': 25, 'VW': 47}

# %%
df1 = df1.drop(index=0)
df2 = df2.drop(index=0)
df3 = df3.drop(index=0)
df4 = df4.drop(index=0)

# %%
df3_code.index = df3.index
df3["Code"] = df3_code

# %%
df3 = df3[['Code'] + [col for col in df3.columns if col != 'Code']]

# %%
df3
# Out:
#         Code 45843K 5743Q3 5743Q4 7516TK 8454C5 7956KV 786H6K 3889EV 5587WH  \
# 1      40179    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      40180    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      40181    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      40182    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5      40183    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 19988  60166    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19989  60167    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19990  60168    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19991  60169    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19992  60170    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#        ... 842A1A 856R3F 208RZ5 225MFY 219J6Q 629XC1 968LDV 9762NU 985WLG  \
# 1      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5      ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 19988  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19989  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19990  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19991  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 19992  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#       808KVH
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# ...      ...
# 19988    NaN
# 19989    NaN
# 19990    NaN
# 19991    NaN
# 19992    NaN
#
# [19992 rows x 151 columns]

# %%
df1.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Dirty_Prices/{country}_cor_dirtyprice.xlsx", index = False)
df2.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_DTM/{country}_cor_dtm.xlsx", index = False)
df3.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Coupon/{country}_cor_coupon.xlsx", index = False)
df4.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Coupon_Dates/{country}.xlsx", index = False)
