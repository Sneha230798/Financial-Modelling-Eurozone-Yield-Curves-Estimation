# %%
import pandas as pd
import numpy as np

# %%
country_done = {'Germany', 'Austria', 'Belgium', 'Finland', 'Ireland', 'Latvia', 'Netherlands', 'France', 'Italy'}

# %%
country = 'Austria'

# %%
df1= pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Dirty_Prices/{country}_cor_dirtyprice.xlsx")
df2= pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_DTM/{country}_cor_dtm.xlsx")
df3= pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Coupon/{country}_cds_normalised.xlsx")
df4 = pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Coupon_Dates/{country}.xlsx")
df5 = pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Macro/Corporate Bonds.xlsm", sheet_name = f'S {country}')

# %%
df3
# Out:
#         Code  6207MZ  8338AF
# 0      40179     NaN     NaN
# 1      40180     NaN     NaN
# 2      40181     NaN     NaN
# 3      40182     NaN     NaN
# 4      40183     NaN     NaN
# ...      ...     ...     ...
# 19987  60166     NaN     NaN
# 19988  60167     NaN     NaN
# 19989  60168     NaN     NaN
# 19990  60169     NaN     NaN
# 19991  60170     NaN     NaN
#
# [19992 rows x 3 columns]

# %%
columns_to_keep = ['Type', 'NIP']

df_filtered = df5.drop(columns=[col for col in df5.columns if col not in columns_to_keep])

dict_type_nip = df_filtered.set_index('Type')['NIP'].to_dict()

# %%
dict_type_nip
# Out:
# {'806DAY': 2,
#  '806DAX': 2,
#  '208W4F': 2,
#  '239GP0': 2,
#  '655Q8F': 1,
#  '655Q7M': 1,
#  '8566JP': 4,
#  '8331YK': 2,
#  '794JCG': 2,
#  '794H97': 2,
#  '842JAK': 2,
#  '842MQZ': 2,
#  '3990T6': 2,
#  '6025EN': 2,
#  '3990TN': 2,
#  '8429H5': 2,
#  '782H9T': 4,
#  '217FUE': 2,
#  '22632T': 2,
#  '8331ZM': 2,
#  '6025EM': 2,
#  '8429KH': 2,
#  '56466L': 2,
#  '5782T1': 4,
#  '5795WN': 4,
#  '5782TW': 4,
#  '807ER1': 1}

# %%
filtered_dict = {key: value for key, value in dict_type_nip.items() if value == 1}

columns_to_keep = df1.columns.intersection(filtered_dict.keys())
df1_filtered = df1[columns_to_keep]

columns_to_keep = df2.columns.intersection(filtered_dict.keys())
df2_filtered = df2[columns_to_keep]

columns_to_keep = df3.columns.intersection(filtered_dict.keys())
df3_filtered = df3[columns_to_keep]

columns_to_keep = df4.columns.intersection(filtered_dict.keys())
df4_filtered = df4[columns_to_keep]

# %%
df2_filtered
# Out:
#       655Q7M  655Q8F
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN
# ...      ...     ...
# 4923  2281.0  3742.0
# 4924  2280.0  3741.0
# 4925  2279.0  3740.0
# 4926  2278.0  3739.0
# 4927  2277.0  3738.0
#
# [4928 rows x 2 columns]

# %%
df1 = df1_filtered
df2 = df2_filtered
df3 = df3_filtered
df4 = df4_filtered

# %%
df5 = pd.read_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_Macro/Corporate Bonds.xlsm", sheet_name = f'{country}')

# %%
df5
# Out:
#                      Name  \
# 0                    Code
# 1     2010-01-01 00:00:00
# 2     2010-01-04 00:00:00
# 3     2010-01-05 00:00:00
# 4     2010-01-06 00:00:00
# ...                   ...
# 3553  2023-08-15 00:00:00
# 3554  2023-08-16 00:00:00
# 3555  2023-08-17 00:00:00
# 3556  2023-08-18 00:00:00
# 3557  2023-08-21 00:00:00
#
#      SMURFIT KAPPA ACQS. 2015 2 3/4% 01/02/25 144A - DEFAULT PRICE  \
# 0                                                806DAY
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3553                                             97.788
# 3554                                             97.764
# 3555                                             97.804
# 3556                                             97.845
# ...

# %%
df5.loc[0] = [str(value).split('(')[0].strip() for value in df5.loc[0]]

# %%
df5
# Out:
#                      Name  \
# 0                    Code
# 1     2010-01-01 00:00:00
# 2     2010-01-04 00:00:00
# 3     2010-01-05 00:00:00
# 4     2010-01-06 00:00:00
# ...                   ...
# 3553  2023-08-15 00:00:00
# 3554  2023-08-16 00:00:00
# 3555  2023-08-17 00:00:00
# 3556  2023-08-18 00:00:00
# 3557  2023-08-21 00:00:00
#
#      SMURFIT KAPPA ACQS. 2015 2 3/4% 01/02/25 144A - DEFAULT PRICE  \
# 0                                                806DAY
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3553                                             97.788
# 3554                                             97.764
# 3555                                             97.804
# 3556                                             97.845
# ...

# %%
dictionary = df5.iloc[0].to_dict()

dictionary2 =  {value: key for key, value in dictionary.items()}

new_key = 'Code'
new_value = 'AAAAAAAAAAAA'

# Append the new key-value pair to the dictionary
dictionary2[new_key] = new_value

# %%
dictionary2
# Out:
# {'Code': 'AAAAAAAAAAAA',
#  '806DAY': 'SMURFIT KAPPA ACQS. 2015 2 3/4% 01/02/25 144A - DEFAULT PRICE',
#  '806DAX': 'SMURFIT KAPPA ACQS. 2015 2 3/4% 01/02/25 REG.S - DEFAULT PRICE',
#  '208W4F': 'SMURFIT KAPPA ACQS. 2018 2 7/8% 15/01/26 REG.S - DEFAULT PRICE',
#  '239GP0': 'SMURFIT KAPPA TRSY. 2019 1 1/2% 15/09/27 REG.S - DEFAULT PRICE',
#  '655Q8F': 'SMURFIT KAPPA TRSY. 2021 1% 22/09/33 REG.S - DEFAULT PRICE',
#  '655Q7M': 'SMURFIT KAPPA TRSY. 2021 1/2% 22/09/29 REG.S - DEFAULT PRICE',
#  '8566JP': 'SMURFIT KAPPA ACQS. 2012 F/R 10/20 EARLY - DEFAULT PRICE',
#  '8331YK': 'SMURFIT KAPPA ACQS. 2013 4 1/8% 30/01/20 EARLY - DEFAULT PRICE',
#  '794JCG': 'SMURFIT KAPPA ACQS. 2014 3 1/4% 01/06/21 EARLY - DEFAULT PRICE',
#  '794H97': 'SMURFIT KAPPA ACQS. 2014 3 1/4% 01/06/21 EARLY - DEFAULT PRICE.1',
#  '842JAK': 'SMURFIT KAPPA ACQS. 2017 2 3/8% 01/02/24 EARLY - DEFAULT PRICE',
#  '842MQZ': 'SMURFIT KAPPA ACQS. 2017 2 3/8% 01/02/24 EARLY - DEFAULT PRICE.1',
# ...

# %%
new_row = [dictionary2[col] for col in df1.columns]

# Insert the new row at the first position in df1
df1.loc[-1] = new_row  # Add new row at the end
df1.index = df1.index + 1  # Shift the index
df1 = df1.sort_index()  # Sort the index so that the new row is at the top

df2.loc[-1] = new_row  # Add new row at the end
df2.index = df2.index + 1  # Shift the index
df2 = df2.sort_index()

df3.loc[-1] = new_row  # Add new row at the end
df3.index = df3.index + 1  # Shift the index
df3 = df3.sort_index()

df4.loc[-1] = new_row  # Add new row at the end
df4.index = df4.index + 1  # Shift the index
df4 = df4.sort_index()
# Out:
# C:\Users\defaultuser0\AppData\Local\Temp\ipykernel_1516\3509888223.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[-1] = new_row  # Add new row at the end

# %%
df1_transposed = df1.transpose()
df1_transposed_sorted = df1_transposed.sort_values(by=0)
df1 = df1_transposed_sorted.transpose()

df2_transposed = df2.transpose()
df2_transposed_sorted = df2_transposed.sort_values(by=0)
df2 = df2_transposed_sorted.transpose()

df3_transposed = df3.transpose()
df3_transposed_sorted = df3_transposed.sort_values(by=0)
df3 = df3_transposed_sorted.transpose()

df4_transposed = df4.transpose()
df4_transposed_sorted = df4_transposed.sort_values(by=0)
df4 = df4_transposed_sorted.transpose()

# %%
df_columns = set(df1.columns)
dict_keys = set(dictionary2.keys())

# Find columns in DataFrame that are not in the dictionary
missing_in_dict = df_columns - dict_keys

# Find keys in the dictionary that are not in the DataFrame columns
extra_in_dict = dict_keys - df_columns

print("Columns in DataFrame not in dictionary:", missing_in_dict)
print("Keys in dictionary not in DataFrame columns:", extra_in_dict)
# Out:
# Columns in DataFrame not in dictionary: set()
# Keys in dictionary not in DataFrame columns: {'8331YK', '806DAX', '6025EM', '8331ZM', '3990T6', '8429KH', 'nan', '806DAY', '8566JP', '794H97', '217FUE', 'Code', '208W4F', '6025EN', '56466L', '842JAK', '842MQZ', '3990TN', '239GP0', '794JCG', '8429H5', '782H9T'}

# %%
df1.loc[0] = [str(value).split()[0] for value in df1.loc[0]]
df2.loc[0] = [str(value).split()[0] for value in df2.loc[0]]
df3.loc[0] = [str(value).split()[0] for value in df3.loc[0]]
df4.loc[0] = [str(value).split()[0] for value in df4.loc[0]]

# %%
row_0_values = df2.loc[0].dropna().unique()  # Drop NaNs and get unique values


all_values = df2.values.flatten()
value_counts = pd.Series(all_values).value_counts()

counts = {value: value_counts.get(value, 0) for value in row_0_values}

print(counts)
# Out:
# {'SMURFIT': 2}

# %%
df1.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Dirty_Prices/{country}_cor_dirtyprice.xlsx", index = False)
df2.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/DTM/{country}_cor_dtm.xlsx", index = False)
df3.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/{country}_cds_normalised.xlsx", index = False)
df4.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon_Dates/{country}.xlsx", index = False)

# %%
df1 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Austria_cds_normalised.xlsx")
df2 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Belgium_cds_normalised.xlsx")
#df3 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Croatia_cds_normalised.xlsx")
#df4 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Cyprus_cds_normalised.xlsx")
#df5 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Estonia_cds_normalised.xlsx")

df6 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Finland_cds_normalised.xlsx")
df7 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/France_cds_normalised.xlsx")
df8 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Germany_cds_normalised.xlsx")
#df9 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Greece_cds_normalised.xlsx")
df10 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Ireland_cds_normalised.xlsx")

df11 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Italy_cds_normalised.xlsx")
df12 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Latvia_cds_normalised.xlsx")
#df13 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Lithuania_cds_normalised.xlsx")
#df14 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Luxembourg_cds_normalised.xlsx")
#df15 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Malta_cds_normalised.xlsx")

df16 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Netherlands_cds_normalised.xlsx")
#df17 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Portugal_cds_normalised.xlsx")
#df18 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Slovakia_cds_normalised.xlsx")
#df19 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Slovenia_cds_normalised.xlsx")
#df20 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Spain_cds_normalised.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df1 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Coupon/Austria_cds_normalised.xlsx")
#       2 df2 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Cor_CDS_Normalised/Coupon/Belgium_cds_normalised.xlsx")
#       3 #df3 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Croatia_cds_normalised.xlsx")
#       4 #df4 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Cyprus_cds_normalised.xlsx")
#       5 #df5 = pd.read_excel("C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/Corporate_all_Euro/Coupon/Estonia_cds_normalised.xlsx")
#
# ...

# %%
dfs = [df1, df2, df6, df7, df8, df10, df11, df12, df16]

# Use pd.concat to merge them side by side (along the columns)
df = pd.concat(dfs, axis=1)

# %%
df
# Out:
#       6207MZ   8338AF 60801X 20111H 55000H 60810E 60835J 37940H 5872U7 60844L  \
# 0        EVN  TELEKOM  AGEAS  AGEAS  AGEAS  AGEAS  AGEAS  AGEAS  AGEAS  AGEAS
# 1        NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2        NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3        NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4        NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...      ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 16508    NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 16509    NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 16510    NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 16511    NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 16512    NaN      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# ...

# %%
df.to_excel(f"C:/Users/defaultuser0/Desktop/Sneha_thesis/excel_files/All Euro/Corporate/Coupon_CDS.xlsx", index = False)
